# %%
# 使用伪码表生成wave从而得到对比训练集，防止恒正运算
# server给subject提供一个伪码表，subject利用伪码表生成对应的对照集
# 伪码与最终的hash key或者BCH code无关
# 判别器需要保留一定的分辨能力
# data index range [2, 66]
import torch
import torch.nn as nn
from torch.nn import *
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import os

from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader

from preprocess_v2 import Process

# %%
seed = 27
def get_random_seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
get_random_seed(seed)

# %%
series = []
items = 1
step = 3
subject_num = 0

for num in range(2, 66):
    try:
        sig, sec_sig = Process(num).prepro(1024, step)
        series += sec_sig
        subject_num += 1
    except:
        print(f'subject {num} abandoned')
# Out:
# subject 13 abandoned
# subject 16 abandoned
# subject 17 abandoned
# subject 18 abandoned
# subject 20 abandoned
# subject 26 abandoned
# /home/dhz/anaconda3/lib/python3.9/site-packages/scipy/interpolate/fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /home/dhz/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:5244: RuntimeWarning: Mean of empty slice.
#   result = super().mean(axis=axis, dtype=dtype, **kwargs)[()]
# /home/dhz/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# subject 42 abandoned
# subject 47 abandoned
# subject 48 abandoned
# subject 50 abandoned

# %%
class MyDataset(Dataset):
    def __init__(self, series, items, subject_num):
        self.series = series
        self.codes = []
        self.subject_num = subject_num
        self.labels = np.zeros((len(self.series), self.subject_num), dtype='double')
        for i in range(self.subject_num):
            for j in range(step - 1):
                self.labels[i * (step - 1) + j][i] = 1.0

    # need to overload
    def __len__(self):
        return len(self.series)

    # need to overload
    def __getitem__(self, idx):
        return self.series[idx], torch.tensor(self.labels[idx])

# %%
dataset = MyDataset(series, items=items, subject_num=subject_num)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=16, shuffle=True)

# %%
class ConvolutionBlock(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(ConvolutionBlock, self).__init__()
        self.block = nn.Sequential(nn.Conv1d(input_size, hidden_size, kernel_size=3, padding=1),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Conv1d(hidden_size, hidden_size, kernel_size=3, padding=1),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU()
        )
        
    def forward(self, x):
        x = self.block(x)
        return x

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers, num_heads, dropout, num_conv_blocks):
        super(TransformerClassifier, self).__init__()
        self.conv1 = ConvolutionBlock(input_size, hidden_size)
        self.conv_blocks = nn.ModuleList([
            ConvolutionBlock(hidden_size, hidden_size) for _ in range(num_conv_blocks)
        ])
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(hidden_size, num_heads, dim_feedforward=hidden_size, dropout=dropout),
            num_layers
        )
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        for conv_block in self.conv_blocks:
            x = conv_block(x)
        x = x.permute(0, 2, 1)  # Reshape to (batch_size, hidden_size, seq_len)
        x = self.transformer(x)
        x = x.mean(dim=1)  # Average the sequence dimension
        x = torch.sigmoid(self.fc(x))
        return x

# %%
device='cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Example usage
input_size = 1
hidden_size = 128
num_classes = 54
num_layers = 6
num_heads = 4
dropout = 0.2
batch_size = 16
num_epochs = 10
num_conv_blocks = 2

# %%
cls = TransformerClassifier(input_size, hidden_size, num_classes, num_layers, num_heads, dropout, num_conv_blocks).to(device)
cls = cls.double()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cls.parameters(), lr=1e-5)
# learning 2e-5, momentum 0.1, rate=50% max = 66.7%
# learning 2e-5, momentum 2e-3, max = 94.4%
# lr 2e-2, momentum 2e-3, max = 67.3%
# with sigmoid
# SGD lr 2e-5 momentum 2e-3 max = 33.3%

# %%
C_loss = []
C_acc = []

# %%
for epoch in range(5000):
    epoch_iterator = tqdm(dataloader, desc="Training Epoch %d" % (epoch + 1), ncols = 100)
    #初始化损失值
    c_epoch_loss = 0
    acc_num = 0
    num = 0
    count = len(dataloader) #返回批次数
    #对数据集进行迭代
    for step, (subject, label) in enumerate(epoch_iterator):
        subject = torch.reshape(subject, (subject.size(0), 1, subject.size(1)))
        subject = subject.to(device) #把数据放到设备上
        label = label.to(device)
        size = subject.size(0)
        num += size
        
        class_train = cls(subject)
        c_loss = criterion(class_train, label)
        c_loss.backward()
        optimizer.step()
        
        for i in range(subject.size(0)):
            idx1 = torch.argmax(class_train[i])
            idx2 = torch.argmax(label[i])
            if idx1 == idx2:
                acc_num += 1
        
        #累计每一个批次的loss
        with torch.no_grad():
            c_epoch_loss += c_loss
        epoch_iterator.set_postfix({"c_loss": '{0:1.5f}'.format(c_epoch_loss), "accuracy": '{0:1.3f}'.format(acc_num / num)})
        epoch_iterator.update(1)
            
    #求平均损失
    with torch.no_grad():
        c_epoch_loss /= count
        acc = acc_num / num
        C_loss.append(c_epoch_loss)
        C_acc.append(acc)
    if acc >=0.9:
        break
# Out:
# Training Epoch 1: 100%|██████████████| 7/7 [00:02<00:00,  2.73it/s, c_loss=27.98122, accuracy=0.028]
# Training Epoch 2: 100%|██████████████| 7/7 [00:00<00:00, 14.32it/s, c_loss=27.93258, accuracy=0.019]
# Training Epoch 3: 100%|██████████████| 7/7 [00:00<00:00, 14.29it/s, c_loss=27.89885, accuracy=0.019]
# Training Epoch 4: 100%|██████████████| 7/7 [00:00<00:00, 13.50it/s, c_loss=27.88528, accuracy=0.046]
# Training Epoch 5: 100%|██████████████| 7/7 [00:00<00:00, 13.36it/s, c_loss=27.85329, accuracy=0.065]
# Training Epoch 6: 100%|██████████████| 7/7 [00:00<00:00, 13.03it/s, c_loss=27.84640, accuracy=0.046]
# Training Epoch 7: 100%|██████████████| 7/7 [00:00<00:00, 13.12it/s, c_loss=27.82171, accuracy=0.037]
# Training Epoch 8: 100%|██████████████| 7/7 [00:00<00:00, 13.37it/s, c_loss=27.81365, accuracy=0.037]
# Training Epoch 9: 100%|██████████████| 7/7 [00:00<00:00, 13.32it/s, c_loss=27.79790, accuracy=0.046]
# Training Epoch 10: 100%|█████████████| 7/7 [00:00<00:00, 12.99it/s, c_loss=27.78666, accuracy=0.074]
# Training Epoch 11: 100%|█████████████| 7/7 [00:00<00:00, 13.40it/s, c_loss=27.76881, accuracy=0.056]
# Training Epoch 12: 100%|█████████████| 7/7 [00:00<00:00, 13.51it/s, c_loss=27.74023, accuracy=0.037]
# Training Epoch 13: 100%|█████████████| 7/7 [00:00<00:00, 11.92it/s, c_loss=27.73534, accuracy=0.056]
# Training Epoch 14: 100%|█████████████| 7/7 [00:00<00:00,  9.12it/s, c_loss=27.71612, accuracy=0.056]
# Training Epoch 15: 100%|█████████████| 7/7 [00:01<00:00,  6.72it/s, c_loss=27.70410, accuracy=0.046]
# Training Epoch 16: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.68833, accuracy=0.046]
# Training Epoch 17: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.68386, accuracy=0.037]
# Training Epoch 18: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.67231, accuracy=0.056]
# Training Epoch 19: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.66111, accuracy=0.056]
# Training Epoch 20: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.61705, accuracy=0.074]
# Training Epoch 21: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.62377, accuracy=0.083]
# Training Epoch 22: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.59338, accuracy=0.083]
# Training Epoch 23: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.57273, accuracy=0.093]
# Training Epoch 24: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.56151, accuracy=0.102]
# Training Epoch 25: 100%|█████████████| 7/7 [00:01<00:00,  6.77it/s, c_loss=27.55484, accuracy=0.093]
# Training Epoch 26: 100%|█████████████| 7/7 [00:01<00:00,  6.79it/s, c_loss=27.54909, accuracy=0.120]
# Training Epoch 27: 100%|█████████████| 7/7 [00:01<00:00,  6.78it/s, c_loss=27.52095, accuracy=0.074]
# Training Epoch 28: 100%|█████████████| 7/7 [00:01<00:00,  6.79it/s, c_loss=27.50343, accuracy=0.083]
# Training Epoch 29: 100%|█████████████| 7/7 [00:01<00:00,  6.79it/s, c_loss=27.50792, accuracy=0.093]
# Training Epoch 30: 100%|█████████████| 7/7 [00:01<00:00,  6.76it/s, c_loss=27.49604, accuracy=0.046]
# Training Epoch 31: 100%|█████████████| 7/7 [00:01<00:00,  6.79it/s, c_loss=27.45395, accuracy=0.083]
# Training Epoch 32: 100%|█████████████| 7/7 [00:01<00:00,  6.80it/s, c_loss=27.45280, accuracy=0.111]
# Training Epoch 33: 100%|█████████████| 7/7 [00:01<00:00,  6.78it/s, c_loss=27.42706, accuracy=0.130]
# Training Epoch 34: 100%|█████████████| 7/7 [00:01<00:00,  6.80it/s, c_loss=27.43176, accuracy=0.083]
# Training Epoch 35: 100%|█████████████| 7/7 [00:01<00:00,  6.79it/s, c_loss=27.40598, accuracy=0.093]
# Training Epoch 36: 100%|█████████████| 7/7 [00:01<00:00,  6.77it/s, c_loss=27.42047, accuracy=0.093]
# Training Epoch 37: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.40165, accuracy=0.056]
# Training Epoch 38: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.40306, accuracy=0.111]
# Training Epoch 39: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.34786, accuracy=0.111]
# Training Epoch 40: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.35743, accuracy=0.130]
# Training Epoch 41: 100%|█████████████| 7/7 [00:01<00:00,  6.72it/s, c_loss=27.33926, accuracy=0.130]
# Training Epoch 42: 100%|█████████████| 7/7 [00:01<00:00,  6.75it/s, c_loss=27.34128, accuracy=0.120]
# Training Epoch 43: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.31725, accuracy=0.176]
# Training Epoch 44: 100%|█████████████| 7/7 [00:01<00:00,  6.75it/s, c_loss=27.28538, accuracy=0.176]
# Training Epoch 45: 100%|█████████████| 7/7 [00:01<00:00,  6.75it/s, c_loss=27.26426, accuracy=0.157]
# Training Epoch 46: 100%|█████████████| 7/7 [00:01<00:00,  6.75it/s, c_loss=27.26506, accuracy=0.185]
# Training Epoch 47: 100%|█████████████| 7/7 [00:01<00:00,  6.73it/s, c_loss=27.23589, accuracy=0.194]
# Training Epoch 48: 100%|█████████████| 7/7 [00:01<00:00,  6.76it/s, c_loss=27.23692, accuracy=0.176]
# Training Epoch 49: 100%|█████████████| 7/7 [00:01<00:00,  6.74it/s, c_loss=27.21252, accuracy=0.194]
# Training Epoch 50: 100%|█████████████| 7/7 [00:01<00:00,  6.76it/s, c_loss=27.22689, accuracy=0.167]
# Training Epoch 51: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.20637, accuracy=0.185]
# Training Epoch 52: 100%|█████████████| 7/7 [00:01<00:00,  6.70it/s, c_loss=27.19007, accuracy=0.167]
# Training Epoch 53: 100%|█████████████| 7/7 [00:01<00:00,  6.70it/s, c_loss=27.17632, accuracy=0.194]
# Training Epoch 54: 100%|█████████████| 7/7 [00:01<00:00,  6.72it/s, c_loss=27.18966, accuracy=0.176]
# Training Epoch 55: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=27.17038, accuracy=0.194]
# Training Epoch 56: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=27.14167, accuracy=0.204]
# Training Epoch 57: 100%|█████████████| 7/7 [00:01<00:00,  6.68it/s, c_loss=27.09140, accuracy=0.213]
# Training Epoch 58: 100%|█████████████| 7/7 [00:01<00:00,  6.70it/s, c_loss=27.12853, accuracy=0.148]
# Training Epoch 59: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.12368, accuracy=0.204]
# Training Epoch 60: 100%|█████████████| 7/7 [00:01<00:00,  6.70it/s, c_loss=27.07976, accuracy=0.213]
# Training Epoch 61: 100%|█████████████| 7/7 [00:01<00:00,  6.70it/s, c_loss=27.07895, accuracy=0.241]
# Training Epoch 62: 100%|█████████████| 7/7 [00:01<00:00,  6.71it/s, c_loss=27.09454, accuracy=0.213]
# Training Epoch 63: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=27.07036, accuracy=0.241]
# Training Epoch 64: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=27.07707, accuracy=0.213]
# Training Epoch 65: 100%|█████████████| 7/7 [00:01<00:00,  6.68it/s, c_loss=27.03786, accuracy=0.185]
# Training Epoch 66: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=27.00007, accuracy=0.213]
# Training Epoch 67: 100%|█████████████| 7/7 [00:01<00:00,  6.69it/s, c_loss=26.97210, accuracy=0.213]
# Training Epoch 68: 100%|█████████████| 7/7 [00:01<00:00,  6.67it/s, c_loss=27.01562, accuracy=0.213]
# Training Epoch 69: 100%|█████████████| 7/7 [00:01<00:00,  6.66it/s, c_loss=27.01301, accuracy=0.194]
# Training Epoch 70: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.99792, accuracy=0.231]
# Training Epoch 71: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=27.00086, accuracy=0.222]
# Training Epoch 72: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.98561, accuracy=0.222]
# Training Epoch 73: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.90821, accuracy=0.167]
# Training Epoch 74: 100%|█████████████| 7/7 [00:01<00:00,  6.67it/s, c_loss=26.94816, accuracy=0.148]
# Training Epoch 75: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.91667, accuracy=0.222]
# Training Epoch 76: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.90546, accuracy=0.194]
# Training Epoch 77: 100%|█████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.94200, accuracy=0.213]
# Training Epoch 78: 100%|█████████████| 7/7 [00:01<00:00,  6.66it/s, c_loss=26.96196, accuracy=0.176]
# Training Epoch 79: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.89306, accuracy=0.204]
# Training Epoch 80: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.89133, accuracy=0.176]
# Training Epoch 81: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.86056, accuracy=0.213]
# Training Epoch 82: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.85550, accuracy=0.259]
# Training Epoch 83: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.85318, accuracy=0.250]
# Training Epoch 84: 100%|█████████████| 7/7 [00:01<00:00,  6.66it/s, c_loss=26.80278, accuracy=0.241]
# Training Epoch 85: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.79363, accuracy=0.222]
# Training Epoch 86: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.76644, accuracy=0.269]
# Training Epoch 87: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.79316, accuracy=0.213]
# Training Epoch 88: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.84671, accuracy=0.204]
# Training Epoch 89: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.78929, accuracy=0.213]
# Training Epoch 90: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.73960, accuracy=0.250]
# Training Epoch 91: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.72240, accuracy=0.306]
# Training Epoch 92: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.69102, accuracy=0.269]
# Training Epoch 93: 100%|█████████████| 7/7 [00:01<00:00,  6.66it/s, c_loss=26.72533, accuracy=0.296]
# Training Epoch 94: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.66873, accuracy=0.287]
# Training Epoch 95: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.71183, accuracy=0.259]
# Training Epoch 96: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.65904, accuracy=0.315]
# Training Epoch 97: 100%|█████████████| 7/7 [00:01<00:00,  6.65it/s, c_loss=26.64870, accuracy=0.241]
# Training Epoch 98: 100%|█████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.69493, accuracy=0.287]
# Training Epoch 99: 100%|█████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.63366, accuracy=0.324]
# Training Epoch 100: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.64151, accuracy=0.296]
# Training Epoch 101: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.62720, accuracy=0.176]
# Training Epoch 102: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.56643, accuracy=0.315]
# Training Epoch 103: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.59583, accuracy=0.296]
# Training Epoch 104: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.55716, accuracy=0.269]
# Training Epoch 105: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.61365, accuracy=0.306]
# Training Epoch 106: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.54984, accuracy=0.278]
# Training Epoch 107: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.50604, accuracy=0.278]
# Training Epoch 108: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.53591, accuracy=0.324]
# Training Epoch 109: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.48878, accuracy=0.287]
# Training Epoch 110: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.54355, accuracy=0.241]
# Training Epoch 111: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.50424, accuracy=0.324]
# Training Epoch 112: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.50712, accuracy=0.278]
# Training Epoch 113: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.52539, accuracy=0.296]
# Training Epoch 114: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.44255, accuracy=0.287]
# Training Epoch 115: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.44605, accuracy=0.287]
# Training Epoch 116: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.41704, accuracy=0.287]
# Training Epoch 117: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.38792, accuracy=0.287]
# Training Epoch 118: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.41510, accuracy=0.250]
# Training Epoch 119: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.41876, accuracy=0.306]
# Training Epoch 120: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.41090, accuracy=0.278]
# Training Epoch 121: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.45225, accuracy=0.287]
# Training Epoch 122: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.37311, accuracy=0.287]
# Training Epoch 123: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.40871, accuracy=0.278]
# Training Epoch 124: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.34647, accuracy=0.250]
# Training Epoch 125: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.36082, accuracy=0.287]
# Training Epoch 126: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.33658, accuracy=0.287]
# Training Epoch 127: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.33561, accuracy=0.296]
# Training Epoch 128: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.32702, accuracy=0.259]
# Training Epoch 129: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.27902, accuracy=0.241]
# Training Epoch 130: 100%|████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=26.29582, accuracy=0.259]
# Training Epoch 131: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.24276, accuracy=0.278]
# Training Epoch 132: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.31659, accuracy=0.259]
# Training Epoch 133: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.30647, accuracy=0.259]
# Training Epoch 134: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.24561, accuracy=0.269]
# Training Epoch 135: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.29146, accuracy=0.296]
# Training Epoch 136: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.23623, accuracy=0.296]
# Training Epoch 137: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.22942, accuracy=0.296]
# Training Epoch 138: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.23646, accuracy=0.241]
# Training Epoch 139: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.22580, accuracy=0.296]
# Training Epoch 140: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.22468, accuracy=0.306]
# Training Epoch 141: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.16849, accuracy=0.278]
# Training Epoch 142: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.18602, accuracy=0.278]
# Training Epoch 143: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.17673, accuracy=0.315]
# Training Epoch 144: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.17881, accuracy=0.278]
# Training Epoch 145: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.18802, accuracy=0.269]
# Training Epoch 146: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.18237, accuracy=0.287]
# Training Epoch 147: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.12154, accuracy=0.306]
# Training Epoch 148: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.19487, accuracy=0.269]
# Training Epoch 149: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.18104, accuracy=0.306]
# Training Epoch 150: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.07526, accuracy=0.296]
# Training Epoch 151: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.07799, accuracy=0.287]
# Training Epoch 152: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.06255, accuracy=0.296]
# Training Epoch 153: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.06350, accuracy=0.287]
# Training Epoch 154: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.08079, accuracy=0.287]
# Training Epoch 155: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.99593, accuracy=0.269]
# Training Epoch 156: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.05976, accuracy=0.250]
# Training Epoch 157: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=26.07710, accuracy=0.269]
# Training Epoch 158: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.95775, accuracy=0.278]
# Training Epoch 159: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=26.01877, accuracy=0.259]
# Training Epoch 160: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.00368, accuracy=0.269]
# Training Epoch 161: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.98389, accuracy=0.296]
# Training Epoch 162: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.03235, accuracy=0.296]
# Training Epoch 163: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.99648, accuracy=0.259]
# Training Epoch 164: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.00073, accuracy=0.287]
# Training Epoch 165: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.99169, accuracy=0.231]
# Training Epoch 166: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.03473, accuracy=0.250]
# Training Epoch 167: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=26.00841, accuracy=0.241]
# Training Epoch 168: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=26.03423, accuracy=0.213]
# Training Epoch 169: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.99556, accuracy=0.241]
# Training Epoch 170: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.93756, accuracy=0.296]
# Training Epoch 171: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.96488, accuracy=0.278]
# Training Epoch 172: 100%|████████████| 7/7 [00:01<00:00,  6.58it/s, c_loss=25.98114, accuracy=0.259]
# Training Epoch 173: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.92014, accuracy=0.250]
# Training Epoch 174: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.90874, accuracy=0.259]
# Training Epoch 175: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.91923, accuracy=0.241]
# Training Epoch 176: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.84555, accuracy=0.324]
# Training Epoch 177: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.86607, accuracy=0.352]
# Training Epoch 178: 100%|████████████| 7/7 [00:01<00:00,  6.59it/s, c_loss=25.81034, accuracy=0.287]
# Training Epoch 179: 100%|████████████| 7/7 [00:01<00:00,  6.59it/s, c_loss=25.81874, accuracy=0.278]
# Training Epoch 180: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.86187, accuracy=0.333]
# Training Epoch 181: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.84155, accuracy=0.269]
# Training Epoch 182: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.80966, accuracy=0.315]
# Training Epoch 183: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.83340, accuracy=0.287]
# Training Epoch 184: 100%|████████████| 7/7 [00:01<00:00,  6.64it/s, c_loss=25.83784, accuracy=0.315]
# Training Epoch 185: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.83906, accuracy=0.296]
# Training Epoch 186: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.82666, accuracy=0.324]
# Training Epoch 187: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.84091, accuracy=0.269]
# Training Epoch 188: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.77557, accuracy=0.343]
# Training Epoch 189: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.76455, accuracy=0.324]
# Training Epoch 190: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.80982, accuracy=0.324]
# Training Epoch 191: 100%|████████████| 7/7 [00:01<00:00,  6.59it/s, c_loss=25.83441, accuracy=0.306]
# Training Epoch 192: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.77074, accuracy=0.324]
# Training Epoch 193: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.78601, accuracy=0.343]
# Training Epoch 194: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.72031, accuracy=0.315]
# Training Epoch 195: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.77778, accuracy=0.259]
# Training Epoch 196: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.74755, accuracy=0.306]
# Training Epoch 197: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.79856, accuracy=0.333]
# Training Epoch 198: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.77690, accuracy=0.324]
# Training Epoch 199: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.69672, accuracy=0.343]
# Training Epoch 200: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.75737, accuracy=0.370]
# Training Epoch 201: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.79218, accuracy=0.315]
# Training Epoch 202: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.78635, accuracy=0.315]
# Training Epoch 203: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.72080, accuracy=0.370]
# Training Epoch 204: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.69779, accuracy=0.296]
# Training Epoch 205: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.75127, accuracy=0.278]
# Training Epoch 206: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.72278, accuracy=0.306]
# Training Epoch 207: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.66685, accuracy=0.315]
# Training Epoch 208: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.69596, accuracy=0.306]
# Training Epoch 209: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.65030, accuracy=0.306]
# Training Epoch 210: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.64409, accuracy=0.306]
# Training Epoch 211: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.62302, accuracy=0.315]
# Training Epoch 212: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.70723, accuracy=0.278]
# Training Epoch 213: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.59811, accuracy=0.352]
# Training Epoch 214: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.66760, accuracy=0.269]
# Training Epoch 215: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.65163, accuracy=0.306]
# Training Epoch 216: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.67634, accuracy=0.269]
# Training Epoch 217: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.64348, accuracy=0.306]
# Training Epoch 218: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.66400, accuracy=0.269]
# Training Epoch 219: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.62026, accuracy=0.278]
# Training Epoch 220: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.62384, accuracy=0.287]
# Training Epoch 221: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.59690, accuracy=0.324]
# Training Epoch 222: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.61063, accuracy=0.250]
# Training Epoch 223: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.58938, accuracy=0.287]
# Training Epoch 224: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.52882, accuracy=0.269]
# Training Epoch 225: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.57558, accuracy=0.306]
# Training Epoch 226: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.60911, accuracy=0.259]
# Training Epoch 227: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.59601, accuracy=0.250]
# Training Epoch 228: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.57770, accuracy=0.259]
# Training Epoch 229: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.53589, accuracy=0.250]
# Training Epoch 230: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.55668, accuracy=0.287]
# Training Epoch 231: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.61725, accuracy=0.269]
# Training Epoch 232: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.57834, accuracy=0.204]
# Training Epoch 233: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.51519, accuracy=0.250]
# Training Epoch 234: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.53597, accuracy=0.259]
# Training Epoch 235: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.55590, accuracy=0.231]
# Training Epoch 236: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.52795, accuracy=0.278]
# Training Epoch 237: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.50393, accuracy=0.259]
# Training Epoch 238: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.46054, accuracy=0.306]
# Training Epoch 239: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.49387, accuracy=0.278]
# Training Epoch 240: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.48443, accuracy=0.278]
# Training Epoch 241: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.49886, accuracy=0.315]
# Training Epoch 242: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.46459, accuracy=0.306]
# Training Epoch 243: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.51915, accuracy=0.269]
# Training Epoch 244: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.40695, accuracy=0.241]
# Training Epoch 245: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.39863, accuracy=0.315]
# Training Epoch 246: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.46609, accuracy=0.287]
# Training Epoch 247: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.46273, accuracy=0.324]
# Training Epoch 248: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.41304, accuracy=0.315]
# Training Epoch 249: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.42128, accuracy=0.306]
# Training Epoch 250: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.42314, accuracy=0.296]
# Training Epoch 251: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.47814, accuracy=0.269]
# Training Epoch 252: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.39896, accuracy=0.296]
# Training Epoch 253: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.43151, accuracy=0.306]
# Training Epoch 254: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.44238, accuracy=0.250]
# Training Epoch 255: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.42956, accuracy=0.287]
# Training Epoch 256: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.42433, accuracy=0.269]
# Training Epoch 257: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.43750, accuracy=0.259]
# Training Epoch 258: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.46092, accuracy=0.213]
# Training Epoch 259: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.39077, accuracy=0.269]
# Training Epoch 260: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.39002, accuracy=0.269]
# Training Epoch 261: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.46618, accuracy=0.269]
# Training Epoch 262: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.37804, accuracy=0.269]
# Training Epoch 263: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.35265, accuracy=0.269]
# Training Epoch 264: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.43511, accuracy=0.250]
# Training Epoch 265: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.30931, accuracy=0.250]
# Training Epoch 266: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.35242, accuracy=0.269]
# Training Epoch 267: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.31849, accuracy=0.278]
# Training Epoch 268: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.38147, accuracy=0.269]
# Training Epoch 269: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.30499, accuracy=0.278]
# Training Epoch 270: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.27193, accuracy=0.278]
# Training Epoch 271: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.24571, accuracy=0.269]
# Training Epoch 272: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.23647, accuracy=0.287]
# Training Epoch 273: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.36318, accuracy=0.287]
# Training Epoch 274: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.27633, accuracy=0.269]
# Training Epoch 275: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.28711, accuracy=0.250]
# Training Epoch 276: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.28617, accuracy=0.315]
# Training Epoch 277: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.35999, accuracy=0.250]
# Training Epoch 278: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.28298, accuracy=0.324]
# Training Epoch 279: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.26813, accuracy=0.278]
# Training Epoch 280: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.27307, accuracy=0.278]
# Training Epoch 281: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.27825, accuracy=0.287]
# Training Epoch 282: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.31858, accuracy=0.241]
# Training Epoch 283: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.43400, accuracy=0.259]
# Training Epoch 284: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.25805, accuracy=0.296]
# Training Epoch 285: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.32480, accuracy=0.287]
# Training Epoch 286: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.26938, accuracy=0.278]
# Training Epoch 287: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.29775, accuracy=0.259]
# Training Epoch 288: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.28476, accuracy=0.296]
# Training Epoch 289: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.31211, accuracy=0.241]
# Training Epoch 290: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.28112, accuracy=0.259]
# Training Epoch 291: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.28223, accuracy=0.324]
# Training Epoch 292: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.24971, accuracy=0.324]
# Training Epoch 293: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.20782, accuracy=0.361]
# Training Epoch 294: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.30304, accuracy=0.315]
# Training Epoch 295: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.19597, accuracy=0.324]
# Training Epoch 296: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.25936, accuracy=0.269]
# Training Epoch 297: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.23002, accuracy=0.352]
# Training Epoch 298: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.26540, accuracy=0.241]
# Training Epoch 299: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.16554, accuracy=0.296]
# Training Epoch 300: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.21328, accuracy=0.287]
# Training Epoch 301: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.21480, accuracy=0.287]
# Training Epoch 302: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.22251, accuracy=0.287]
# Training Epoch 303: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.16019, accuracy=0.315]
# Training Epoch 304: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.17639, accuracy=0.269]
# Training Epoch 305: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.17952, accuracy=0.315]
# Training Epoch 306: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.13418, accuracy=0.324]
# Training Epoch 307: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.12749, accuracy=0.278]
# Training Epoch 308: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.19915, accuracy=0.259]
# Training Epoch 309: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.18569, accuracy=0.306]
# Training Epoch 310: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.18552, accuracy=0.315]
# Training Epoch 311: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.16726, accuracy=0.296]
# Training Epoch 312: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.16816, accuracy=0.306]
# Training Epoch 313: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.14841, accuracy=0.333]
# Training Epoch 314: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.17562, accuracy=0.287]
# Training Epoch 315: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.12487, accuracy=0.343]
# Training Epoch 316: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.12348, accuracy=0.324]
# Training Epoch 317: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.12987, accuracy=0.324]
# Training Epoch 318: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.09911, accuracy=0.343]
# Training Epoch 319: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.13672, accuracy=0.306]
# Training Epoch 320: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.15405, accuracy=0.333]
# Training Epoch 321: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.24781, accuracy=0.269]
# Training Epoch 322: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.18048, accuracy=0.306]
# Training Epoch 323: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.15619, accuracy=0.324]
# Training Epoch 324: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.15289, accuracy=0.324]
# Training Epoch 325: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.15233, accuracy=0.315]
# Training Epoch 326: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.13578, accuracy=0.287]
# Training Epoch 327: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.07869, accuracy=0.352]
# Training Epoch 328: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.16203, accuracy=0.287]
# Training Epoch 329: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=25.07984, accuracy=0.352]
# Training Epoch 330: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.01168, accuracy=0.315]
# Training Epoch 331: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.10284, accuracy=0.296]
# Training Epoch 332: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.00938, accuracy=0.306]
# Training Epoch 333: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.98522, accuracy=0.324]
# Training Epoch 334: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.01249, accuracy=0.306]
# Training Epoch 335: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.99265, accuracy=0.361]
# Training Epoch 336: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.06226, accuracy=0.324]
# Training Epoch 337: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.01657, accuracy=0.269]
# Training Epoch 338: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.00864, accuracy=0.306]
# Training Epoch 339: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.04430, accuracy=0.296]
# Training Epoch 340: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.99888, accuracy=0.315]
# Training Epoch 341: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.00435, accuracy=0.306]
# Training Epoch 342: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.01817, accuracy=0.250]
# Training Epoch 343: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.03899, accuracy=0.333]
# Training Epoch 344: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.06315, accuracy=0.259]
# Training Epoch 345: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.97204, accuracy=0.287]
# Training Epoch 346: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.98758, accuracy=0.278]
# Training Epoch 347: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.06617, accuracy=0.315]
# Training Epoch 348: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=25.06117, accuracy=0.250]
# Training Epoch 349: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=25.03414, accuracy=0.278]
# Training Epoch 350: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.96872, accuracy=0.296]
# Training Epoch 351: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.97466, accuracy=0.315]
# Training Epoch 352: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.94273, accuracy=0.324]
# Training Epoch 353: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.91658, accuracy=0.333]
# Training Epoch 354: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.95194, accuracy=0.278]
# Training Epoch 355: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.99065, accuracy=0.287]
# Training Epoch 356: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.92213, accuracy=0.352]
# Training Epoch 357: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.93783, accuracy=0.324]
# Training Epoch 358: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.00628, accuracy=0.306]
# Training Epoch 359: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.99783, accuracy=0.269]
# Training Epoch 360: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=25.05414, accuracy=0.287]
# Training Epoch 361: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.95610, accuracy=0.315]
# Training Epoch 362: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.98980, accuracy=0.306]
# Training Epoch 363: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.91173, accuracy=0.324]
# Training Epoch 364: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.94835, accuracy=0.324]
# Training Epoch 365: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.96650, accuracy=0.361]
# Training Epoch 366: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.94798, accuracy=0.306]
# Training Epoch 367: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.98454, accuracy=0.324]
# Training Epoch 368: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.94104, accuracy=0.296]
# Training Epoch 369: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.97020, accuracy=0.287]
# Training Epoch 370: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.95994, accuracy=0.222]
# Training Epoch 371: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.91155, accuracy=0.306]
# Training Epoch 372: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.94287, accuracy=0.333]
# Training Epoch 373: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.94261, accuracy=0.296]
# Training Epoch 374: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.91234, accuracy=0.389]
# Training Epoch 375: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.85818, accuracy=0.343]
# Training Epoch 376: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.88255, accuracy=0.296]
# Training Epoch 377: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.87770, accuracy=0.343]
# Training Epoch 378: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.85407, accuracy=0.398]
# Training Epoch 379: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.89695, accuracy=0.287]
# Training Epoch 380: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.86190, accuracy=0.370]
# Training Epoch 381: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.94439, accuracy=0.324]
# Training Epoch 382: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.91422, accuracy=0.306]
# Training Epoch 383: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.84897, accuracy=0.315]
# Training Epoch 384: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.84168, accuracy=0.361]
# Training Epoch 385: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.90044, accuracy=0.324]
# Training Epoch 386: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.82461, accuracy=0.370]
# Training Epoch 387: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.80994, accuracy=0.361]
# Training Epoch 388: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.78995, accuracy=0.352]
# Training Epoch 389: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.81436, accuracy=0.389]
# Training Epoch 390: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.83680, accuracy=0.370]
# Training Epoch 391: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.84014, accuracy=0.333]
# Training Epoch 392: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.90434, accuracy=0.343]
# Training Epoch 393: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.85138, accuracy=0.296]
# Training Epoch 394: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.77615, accuracy=0.398]
# Training Epoch 395: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.82679, accuracy=0.352]
# Training Epoch 396: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.86515, accuracy=0.333]
# Training Epoch 397: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.87909, accuracy=0.352]
# Training Epoch 398: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.82185, accuracy=0.324]
# Training Epoch 399: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.86912, accuracy=0.287]
# Training Epoch 400: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.84934, accuracy=0.361]
# Training Epoch 401: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.85558, accuracy=0.287]
# Training Epoch 402: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.80588, accuracy=0.324]
# Training Epoch 403: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.79584, accuracy=0.324]
# Training Epoch 404: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.81475, accuracy=0.333]
# Training Epoch 405: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.78875, accuracy=0.352]
# Training Epoch 406: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.76830, accuracy=0.370]
# Training Epoch 407: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.81162, accuracy=0.352]
# Training Epoch 408: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.77822, accuracy=0.343]
# Training Epoch 409: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.77811, accuracy=0.324]
# Training Epoch 410: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.77010, accuracy=0.352]
# Training Epoch 411: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.75847, accuracy=0.407]
# Training Epoch 412: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.78914, accuracy=0.352]
# Training Epoch 413: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.76313, accuracy=0.426]
# Training Epoch 414: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.73912, accuracy=0.389]
# Training Epoch 415: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.76032, accuracy=0.417]
# Training Epoch 416: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.80796, accuracy=0.343]
# Training Epoch 417: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.76701, accuracy=0.361]
# Training Epoch 418: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.73923, accuracy=0.389]
# Training Epoch 419: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.78719, accuracy=0.407]
# Training Epoch 420: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.81672, accuracy=0.343]
# Training Epoch 421: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.76892, accuracy=0.343]
# Training Epoch 422: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.78247, accuracy=0.398]
# Training Epoch 423: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.70355, accuracy=0.426]
# Training Epoch 424: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.77056, accuracy=0.380]
# Training Epoch 425: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.74996, accuracy=0.454]
# Training Epoch 426: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.75077, accuracy=0.352]
# Training Epoch 427: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.71194, accuracy=0.370]
# Training Epoch 428: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.71690, accuracy=0.389]
# Training Epoch 429: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.73732, accuracy=0.333]
# Training Epoch 430: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.67780, accuracy=0.370]
# Training Epoch 431: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.75744, accuracy=0.361]
# Training Epoch 432: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.73507, accuracy=0.380]
# Training Epoch 433: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.74600, accuracy=0.352]
# Training Epoch 434: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.78073, accuracy=0.278]
# Training Epoch 435: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.71512, accuracy=0.352]
# Training Epoch 436: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.69741, accuracy=0.343]
# Training Epoch 437: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.69482, accuracy=0.370]
# Training Epoch 438: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.68570, accuracy=0.324]
# Training Epoch 439: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.75861, accuracy=0.315]
# Training Epoch 440: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.69473, accuracy=0.361]
# Training Epoch 441: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.69015, accuracy=0.352]
# Training Epoch 442: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.64965, accuracy=0.389]
# Training Epoch 443: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.66934, accuracy=0.343]
# Training Epoch 444: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.65395, accuracy=0.380]
# Training Epoch 445: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.65227, accuracy=0.315]
# Training Epoch 446: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.67822, accuracy=0.324]
# Training Epoch 447: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.62404, accuracy=0.370]
# Training Epoch 448: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.64144, accuracy=0.324]
# Training Epoch 449: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.65869, accuracy=0.370]
# Training Epoch 450: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.58912, accuracy=0.361]
# Training Epoch 451: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.78434, accuracy=0.296]
# Training Epoch 452: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.61312, accuracy=0.352]
# Training Epoch 453: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.61221, accuracy=0.324]
# Training Epoch 454: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.60468, accuracy=0.306]
# Training Epoch 455: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.63309, accuracy=0.306]
# Training Epoch 456: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.61610, accuracy=0.352]
# Training Epoch 457: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.63286, accuracy=0.361]
# Training Epoch 458: 100%|████████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=24.58041, accuracy=0.306]
# Training Epoch 459: 100%|████████████| 7/7 [00:01<00:00,  6.59it/s, c_loss=24.60400, accuracy=0.315]
# Training Epoch 460: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.66184, accuracy=0.269]
# Training Epoch 461: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.59785, accuracy=0.352]
# Training Epoch 462: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.54161, accuracy=0.352]
# Training Epoch 463: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.58277, accuracy=0.361]
# Training Epoch 464: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.55091, accuracy=0.333]
# Training Epoch 465: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.58433, accuracy=0.324]
# Training Epoch 466: 100%|████████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=24.58438, accuracy=0.361]
# Training Epoch 467: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.54381, accuracy=0.398]
# Training Epoch 468: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.57927, accuracy=0.361]
# Training Epoch 469: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.58166, accuracy=0.370]
# Training Epoch 470: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.57143, accuracy=0.324]
# Training Epoch 471: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.58101, accuracy=0.389]
# Training Epoch 472: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.59284, accuracy=0.333]
# Training Epoch 473: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.53849, accuracy=0.389]
# Training Epoch 474: 100%|████████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=24.59919, accuracy=0.343]
# Training Epoch 475: 100%|████████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=24.68213, accuracy=0.315]
# ...
# Training Epoch 4843: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45672, accuracy=0.833]
# Training Epoch 4844: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44582, accuracy=0.815]
# Training Epoch 4845: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.48055, accuracy=0.806]
# Training Epoch 4846: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45481, accuracy=0.796]
# Training Epoch 4847: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46485, accuracy=0.806]
# Training Epoch 4848: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46039, accuracy=0.824]
# Training Epoch 4849: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46319, accuracy=0.806]
# Training Epoch 4850: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44996, accuracy=0.815]
# Training Epoch 4851: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.53195, accuracy=0.796]
# Training Epoch 4852: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45869, accuracy=0.796]
# Training Epoch 4853: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.49734, accuracy=0.824]
# Training Epoch 4854: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.50739, accuracy=0.806]
# Training Epoch 4855: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48652, accuracy=0.796]
# Training Epoch 4856: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46848, accuracy=0.796]
# Training Epoch 4857: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45266, accuracy=0.787]
# Training Epoch 4858: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48589, accuracy=0.806]
# Training Epoch 4859: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.47738, accuracy=0.796]
# Training Epoch 4860: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46940, accuracy=0.796]
# Training Epoch 4861: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49025, accuracy=0.806]
# Training Epoch 4862: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46784, accuracy=0.769]
# Training Epoch 4863: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47307, accuracy=0.796]
# Training Epoch 4864: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.48691, accuracy=0.796]
# Training Epoch 4865: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47648, accuracy=0.806]
# Training Epoch 4866: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46633, accuracy=0.824]
# Training Epoch 4867: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49545, accuracy=0.815]
# Training Epoch 4868: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46364, accuracy=0.815]
# Training Epoch 4869: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46885, accuracy=0.815]
# Training Epoch 4870: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.53263, accuracy=0.833]
# Training Epoch 4871: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48790, accuracy=0.796]
# Training Epoch 4872: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46868, accuracy=0.796]
# Training Epoch 4873: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.46477, accuracy=0.815]
# Training Epoch 4874: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49553, accuracy=0.796]
# Training Epoch 4875: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.46230, accuracy=0.852]
# Training Epoch 4876: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47064, accuracy=0.815]
# Training Epoch 4877: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46823, accuracy=0.806]
# Training Epoch 4878: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45013, accuracy=0.833]
# Training Epoch 4879: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47232, accuracy=0.843]
# Training Epoch 4880: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47449, accuracy=0.852]
# Training Epoch 4881: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47632, accuracy=0.833]
# Training Epoch 4882: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46379, accuracy=0.843]
# Training Epoch 4883: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45495, accuracy=0.833]
# Training Epoch 4884: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48193, accuracy=0.852]
# Training Epoch 4885: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.49192, accuracy=0.852]
# Training Epoch 4886: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.56605, accuracy=0.824]
# Training Epoch 4887: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45519, accuracy=0.833]
# Training Epoch 4888: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46742, accuracy=0.824]
# Training Epoch 4889: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49012, accuracy=0.833]
# Training Epoch 4890: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46369, accuracy=0.852]
# Training Epoch 4891: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.46585, accuracy=0.833]
# Training Epoch 4892: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47617, accuracy=0.824]
# Training Epoch 4893: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47016, accuracy=0.861]
# Training Epoch 4894: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.46498, accuracy=0.852]
# Training Epoch 4895: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.49029, accuracy=0.861]
# Training Epoch 4896: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48943, accuracy=0.815]
# Training Epoch 4897: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.48235, accuracy=0.833]
# Training Epoch 4898: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.49209, accuracy=0.843]
# Training Epoch 4899: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.46465, accuracy=0.824]
# Training Epoch 4900: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49647, accuracy=0.824]
# Training Epoch 4901: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47000, accuracy=0.861]
# Training Epoch 4902: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46678, accuracy=0.824]
# Training Epoch 4903: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.44515, accuracy=0.806]
# Training Epoch 4904: 100%|███████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=21.46350, accuracy=0.806]
# Training Epoch 4905: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48917, accuracy=0.833]
# Training Epoch 4906: 100%|███████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=21.44987, accuracy=0.806]
# Training Epoch 4907: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44614, accuracy=0.870]
# Training Epoch 4908: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46879, accuracy=0.833]
# Training Epoch 4909: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46177, accuracy=0.824]
# Training Epoch 4910: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.44940, accuracy=0.815]
# Training Epoch 4911: 100%|███████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=21.46791, accuracy=0.806]
# Training Epoch 4912: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45760, accuracy=0.833]
# Training Epoch 4913: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.50479, accuracy=0.815]
# Training Epoch 4914: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.56095, accuracy=0.796]
# Training Epoch 4915: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46458, accuracy=0.833]
# Training Epoch 4916: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47390, accuracy=0.824]
# Training Epoch 4917: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48609, accuracy=0.815]
# Training Epoch 4918: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47255, accuracy=0.796]
# Training Epoch 4919: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.47353, accuracy=0.787]
# Training Epoch 4920: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.48141, accuracy=0.824]
# Training Epoch 4921: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46605, accuracy=0.796]
# Training Epoch 4922: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.44804, accuracy=0.806]
# Training Epoch 4923: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46379, accuracy=0.815]
# Training Epoch 4924: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45767, accuracy=0.806]
# Training Epoch 4925: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47701, accuracy=0.778]
# Training Epoch 4926: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47041, accuracy=0.806]
# Training Epoch 4927: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45128, accuracy=0.824]
# Training Epoch 4928: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47811, accuracy=0.815]
# Training Epoch 4929: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45073, accuracy=0.824]
# Training Epoch 4930: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45079, accuracy=0.833]
# Training Epoch 4931: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46508, accuracy=0.815]
# Training Epoch 4932: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.44694, accuracy=0.815]
# Training Epoch 4933: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44667, accuracy=0.815]
# Training Epoch 4934: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45417, accuracy=0.824]
# Training Epoch 4935: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46042, accuracy=0.806]
# Training Epoch 4936: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47587, accuracy=0.787]
# Training Epoch 4937: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45233, accuracy=0.833]
# Training Epoch 4938: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46647, accuracy=0.815]
# Training Epoch 4939: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46384, accuracy=0.806]
# Training Epoch 4940: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.44549, accuracy=0.815]
# Training Epoch 4941: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47430, accuracy=0.806]
# Training Epoch 4942: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47518, accuracy=0.787]
# Training Epoch 4943: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47229, accuracy=0.824]
# Training Epoch 4944: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46650, accuracy=0.833]
# Training Epoch 4945: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45875, accuracy=0.852]
# Training Epoch 4946: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.48533, accuracy=0.815]
# Training Epoch 4947: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.48307, accuracy=0.824]
# Training Epoch 4948: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46233, accuracy=0.824]
# Training Epoch 4949: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.47056, accuracy=0.815]
# Training Epoch 4950: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47459, accuracy=0.843]
# Training Epoch 4951: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46683, accuracy=0.824]
# Training Epoch 4952: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47999, accuracy=0.833]
# Training Epoch 4953: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46148, accuracy=0.843]
# Training Epoch 4954: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45915, accuracy=0.815]
# Training Epoch 4955: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45958, accuracy=0.833]
# Training Epoch 4956: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.51934, accuracy=0.824]
# Training Epoch 4957: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.47073, accuracy=0.824]
# Training Epoch 4958: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.50586, accuracy=0.796]
# Training Epoch 4959: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45228, accuracy=0.824]
# Training Epoch 4960: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46833, accuracy=0.787]
# Training Epoch 4961: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.43472, accuracy=0.843]
# Training Epoch 4962: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45258, accuracy=0.852]
# Training Epoch 4963: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.48509, accuracy=0.843]
# Training Epoch 4964: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44140, accuracy=0.806]
# Training Epoch 4965: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.43595, accuracy=0.824]
# Training Epoch 4966: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44863, accuracy=0.796]
# Training Epoch 4967: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45383, accuracy=0.824]
# Training Epoch 4968: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.53002, accuracy=0.806]
# Training Epoch 4969: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44761, accuracy=0.843]
# Training Epoch 4970: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44788, accuracy=0.778]
# Training Epoch 4971: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46241, accuracy=0.815]
# Training Epoch 4972: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45033, accuracy=0.861]
# Training Epoch 4973: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.44386, accuracy=0.815]
# Training Epoch 4974: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46741, accuracy=0.852]
# Training Epoch 4975: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44557, accuracy=0.824]
# Training Epoch 4976: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46272, accuracy=0.861]
# Training Epoch 4977: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44424, accuracy=0.824]
# Training Epoch 4978: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.44804, accuracy=0.852]
# Training Epoch 4979: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45295, accuracy=0.843]
# Training Epoch 4980: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.49619, accuracy=0.843]
# Training Epoch 4981: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47266, accuracy=0.796]
# Training Epoch 4982: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45835, accuracy=0.833]
# Training Epoch 4983: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47620, accuracy=0.852]
# Training Epoch 4984: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.44812, accuracy=0.824]
# Training Epoch 4985: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45174, accuracy=0.787]
# Training Epoch 4986: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.59586, accuracy=0.806]
# Training Epoch 4987: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49112, accuracy=0.796]
# Training Epoch 4988: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49381, accuracy=0.806]
# Training Epoch 4989: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.50323, accuracy=0.852]
# Training Epoch 4990: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.49973, accuracy=0.833]
# Training Epoch 4991: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45843, accuracy=0.843]
# Training Epoch 4992: 100%|███████████| 7/7 [00:01<00:00,  6.63it/s, c_loss=21.44807, accuracy=0.824]
# Training Epoch 4993: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.46525, accuracy=0.861]
# Training Epoch 4994: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.56816, accuracy=0.815]
# Training Epoch 4995: 100%|███████████| 7/7 [00:01<00:00,  6.60it/s, c_loss=21.45206, accuracy=0.815]
# Training Epoch 4996: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.47351, accuracy=0.815]
# Training Epoch 4997: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45347, accuracy=0.843]
# Training Epoch 4998: 100%|███████████| 7/7 [00:01<00:00,  6.62it/s, c_loss=21.45062, accuracy=0.833]
# Training Epoch 4999: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.46116, accuracy=0.833]
# Training Epoch 5000: 100%|███████████| 7/7 [00:01<00:00,  6.61it/s, c_loss=21.45921, accuracy=0.824]

# %%
c_curve = [i.cpu() for i in C_loss]
plt.plot(c_curve)

# %%
a_curve = [i for i in C_acc]
plt.plot(a_curve)

# %%
np.save('c_curve_v2.npy', c_curve)
np.save('a_curve_v2.npy', a_curve)

# %%
torch.save(cls, "classification_v2")
