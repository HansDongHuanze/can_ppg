# %%
#导入库
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import data
import torchvision #加载图片
from torchvision import transforms #图片变换

from torch.utils.data.dataset import Dataset
from torch.utils.data.dataloader import DataLoader
 
import numpy as np
import matplotlib.pyplot as plt #绘图
import os
import glob
from PIL import Image
import random

from preprocess import Process
from transformer import *

# %%
seed = 32
def get_random_seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
get_random_seed(seed)

# %%
#独热编码
def one_hot(x,class_count=10):
    return torch.eye(class_count)[x,:]

# %%
series = []
items = 3
step = 3
subject_num = 0

for num in range(2, 66):
    try:
        series += Process(num).prepro(1024, step, items)
        subject_num += 1
    except:
        print(f'subject {num} abandoned')
# Out:
# subject 13 abandoned
# subject 16 abandoned
# subject 17 abandoned
# subject 18 abandoned
# subject 20 abandoned
# subject 26 abandoned
# /home/dhz/anaconda3/lib/python3.9/site-packages/scipy/interpolate/fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /home/dhz/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:5244: RuntimeWarning: Mean of empty slice.
#   result = super().mean(axis=axis, dtype=dtype, **kwargs)[()]
# /home/dhz/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# subject 42 abandoned
# subject 47 abandoned
# subject 48 abandoned
# subject 50 abandoned

# %%
class MyDataset(Dataset):
    def __init__(self, series, items, subject_num):
        self.series = series
        self.codes = []
        self.subject_num = subject_num
        self.labels = np.zeros((len(self.series), self.subject_num), dtype='double')
        for i in range(self.subject_num):
            for j in range(items):
                self.labels[i + j][i] = 1.0            

    # need to overload
    def __len__(self):
        return len(self.series)

    # need to overload
    def __getitem__(self, idx):
        return torch.tensor(self.series[idx]), torch.tensor(self.labels[idx])

# %%
dataset = MyDataset(series, items=items, subject_num=subject_num)
dataloader = torch.utils.data.DataLoader(dataset,batch_size=16)

# %%
#定义生成器
class Generator(nn.Module):
    def __init__(self, subject_num):
        super(Generator,self).__init__()
        self.linear1 = nn.Linear(100,512)
        self.bn1=nn.BatchNorm1d(512)
        self.subject_num = subject_num
        self.linear2 = nn.Linear(subject_num,512)
        self.bn2=nn.BatchNorm1d(512)
        
        self.deconv1 = nn.Conv1d(1, 3, kernel_size=2, padding='same')
        self.bn3=nn.BatchNorm1d(3)
        self.deconv2 = nn.Conv1d(3, 6, kernel_size=2, padding='same')
        self.bn4=nn.BatchNorm1d(6)
        self.deconv3 = nn.Conv1d(6, 1, kernel_size=2, padding='same')
        
    def forward(self,x1,x2):
        x1=F.relu(self.linear1(x1.to(torch.float64)))
        x1=self.bn1(x1)
        x2=F.relu(self.linear2(x2))
        x2=self.bn2(x2)
        x=torch.cat([x1,x2],axis=1)
        x=F.relu(self.deconv1(torch.reshape(x, (x.size(0), 1, x.size(1)))))
        x=self.bn3(x)
        x=F.relu(self.deconv2(x))
        x=self.bn4(x)
        x=torch.tanh(self.deconv3(x))
        return x

# %%
#定义判别器
#输入：1，28，28图片和长度为10的condition
class Discriminator(nn.Module):
    def __init__(self, subject_num):
        super(Discriminator,self).__init__()
        self.subject_num = subject_num
        self.linear = nn.Linear(self.subject_num,1024)
        self.conv1 = nn.Conv1d(1,32,kernel_size=2,padding='same')
        self.conv2 = nn.Conv1d(32,128,kernel_size=2,padding='same')
        self.bn = nn.BatchNorm1d(128)
        self.fc = nn.Linear(2048,1)
    def forward(self,x1,x2): #x1代表label,x2代表image
        x1=F.leaky_relu(self.linear(x1))
        x=torch.cat([x1,x2],axis=1)            
        x= F.dropout1d(F.leaky_relu(self.conv1(torch.reshape(x, (x.size(0), 1, x.size(1))))))
        x= F.dropout1d(F.leaky_relu(self.conv2(x)))
        x = self.bn(x)
        x = torch.sigmoid(self.fc(x))
        return x

# %%
class ContinuityLoss(nn.Module):
    def __init__(self, weight=1.0):
        super(ContinuityLoss, self).__init__()
        self.weight = weight
        
    def forward(self, predictions):
        diff = predictions[:][1:] - predictions[:][:-1]
        loss = torch.mean(torch.abs(diff))
        return loss * self.weight

# %%
class MaxValueLoss(nn.Module):
    def __init__(self, weight=1.0):
        super(MaxValueLoss, self).__init__()
        self.weight = weight
        self.MCE = nn.CrossEntropyLoss()
    def forward(self, input1):
        input2 = torch.zeros_like(input1)
        types = torch.argmax(input1, dim = 0, keepdim=False)
        for i in range(input1.size(0)):
            input2[i][types[i]] = 1
        loss = self.MCE(input1, input2)
        return loss * self.weight

# %%
class ClassLoss(nn.Module):
    def __init__(self, weight=1.0):
        super(ClassLoss, self).__init__()
        self.weight = weight
    def forward(self, input1, input2):
        diff = input1 - input2
        loss = torch.mean(torch.abs(diff))
        return loss * self.weight

# %%
class ClassLoss(nn.Module):
    def __init__(self, weight=1.0):
        super(ClassLoss, self).__init__()
        self.weight = weight
        self.MCE = nn.CrossEntropyLoss()
    def forward(self, input1, input2):
        loss = self.MCE(input1, input2)
        return loss * self.weight

# %%
#设备的配置
device='cuda' if torch.cuda.is_available() else 'cpu'
#初化生成器和判别器把他们放到相应的设备上
gen = Generator(subject_num).to(device)
gen = gen.double()
dis = Discriminator(subject_num).to(device)
dis = dis.double()
cls = torch.load("classification").to(device)
cls = cls.double()
#交叉熵损失函数
loss_fn = torch.nn.BCELoss()
continue_loss_weight = 1
continue_loss = ContinuityLoss(weight=continue_loss_weight)
class_loss_weight = 0.1
class_loss = ClassLoss(weight=class_loss_weight)
#训练器的优化器
discriminator_rate = 1e-5
generator_rate = 1e-4
d_optimizer = torch.optim.Adam(dis.parameters(),lr=discriminator_rate)
#训练生成器的优化器
g_optimizer = torch.optim.Adam(gen.parameters(),lr=generator_rate)

# %%
#设置生成绘图图片的随机张量，这里可视化16张图片
#生成16个长度为100的随机正态分布张量
noise_seed = torch.randn(16,100,device=device)
label_seed = torch.randint(0,subject_num,size=(16,))
label_seed_onehot = one_hot(label_seed, class_count=subject_num).to(device)
 
D_loss = [] #记录训练过程中判别器的损失
G_loss = [] #记录训练过程中生成器的损失
S_loss = []
C_loss = []
accs = []
epoch_num = 4000

# %%
#训练循环
for epoch in range(epoch_num):
    #初始化损失值
    D_epoch_loss = 0
    G_epoch_loss = 0
    C_epoch_loss = 0
    S_epoch_loss = 0
    acc_num = 0
    item_num = 0
    count = len(dataloader.dataset) #返回批次数
    #对数据集进行迭代
    for step,(img,label) in enumerate(dataloader):
        img =img.to(device) #把数据放到设备上
        label = label.to(device)
        size = img.shape[0] #img的第一位是size,获取批次的大小
        random_seed = torch.randn(size,100,device=device)
        item_num += size
        
        #判别器训练(真实图片的损失和生成图片的损失),损失的构建和优化
        d_optimizer.zero_grad()#梯度归零
        #判别器对于真实图片产生的损失
        real_output = dis(label,img) #判别器输入真实的图片，real_output对真实图片的预测结果
        d_real_loss = loss_fn(real_output,
                              torch.ones_like(real_output,device=device)
                              )
        d_real_loss.backward()#计算梯度
        
        #在生成器上去计算生成器的损失，优化目标是判别器上的参数
        generated_img = gen(random_seed,label) #得到生成的图片
        
        #因为优化目标是判别器，所以对生成器上的优化目标进行截断
        generated_img = torch.reshape(generated_img, (generated_img.size(0), generated_img.size(2)))
        fake_output = dis(label,generated_img.detach()) #判别器输入生成的图片，fake_output对生成图片的预测;detach会截断梯度，梯度就不会再传递到gen模型中了
        #判别器在生成图像上产生的损失
        d_fake_loss = loss_fn(fake_output,
                              torch.zeros_like(fake_output,device=device)
                              )
        d_fake_loss.backward()
        #判别器损失
        disc_loss = d_real_loss + d_fake_loss
        #判别器优化
        d_optimizer.step()
        
        
        #生成器上损失的构建和优化
        g_optimizer.zero_grad() #先将生成器上的梯度置零
        fake_output = dis(label,generated_img)
        class_output = cls(torch.reshape(generated_img, (generated_img.size(0), 1, generated_img.size(1))))
        cls_loss = class_loss(class_output, label)
        series_loss = continue_loss(generated_img)
        for i in range(size):
            if class_output[i][torch.argmax(label[i])] >= 0.5:
                acc_num += 1
        gen_loss = loss_fn(fake_output,
                              torch.ones_like(fake_output,device=device)
                          ) + series_loss + cls_loss
        gen_loss.backward()
        g_optimizer.step()
        #累计每一个批次的loss
        with torch.no_grad():
            D_epoch_loss +=disc_loss
            G_epoch_loss +=gen_loss
            S_epoch_loss +=series_loss
            C_epoch_loss +=cls_loss
    #求平均损失
    with torch.no_grad():
        D_epoch_loss /=count
        G_epoch_loss /=count
        S_epoch_loss /=(count * continue_loss_weight)
        C_epoch_loss /=(count * class_loss_weight)
        acc = acc_num / item_num
        D_loss.append(D_epoch_loss)
        G_loss.append(G_epoch_loss)
        S_loss.append(S_epoch_loss)
        C_loss.append(C_epoch_loss)
        accs.append(acc)
        print(f"Epoch [{epoch + 1}/{epoch_num}], "
              f"Discriminator Loss: {D_epoch_loss:.4f}, "
              f"Generator Loss: {G_epoch_loss:.4f}, "
              f"Series Loss: {S_epoch_loss:.4f}, "
              f"Class Loss: {C_epoch_loss:.4f}, "
              f"Accuracy: {acc:.4f}")
        if acc > 0.8:
            break
# Out:
# /home/dhz/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py:309: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return F.conv1d(input, weight, bias, self.stride,
# Epoch [1/4000], Discriminator Loss: 0.1067, Generator Loss: 0.1035, Series Loss: 0.0261, Class Loss: 0.2496, Accuracy: 0.0741
# Epoch [2/4000], Discriminator Loss: 0.1031, Generator Loss: 0.1009, Series Loss: 0.0259, Class Loss: 0.2495, Accuracy: 0.0864
# Epoch [3/4000], Discriminator Loss: 0.1004, Generator Loss: 0.0990, Series Loss: 0.0254, Class Loss: 0.2494, Accuracy: 0.0926
# Epoch [4/4000], Discriminator Loss: 0.0986, Generator Loss: 0.0977, Series Loss: 0.0251, Class Loss: 0.2492, Accuracy: 0.0926
# Epoch [5/4000], Discriminator Loss: 0.0970, Generator Loss: 0.0968, Series Loss: 0.0248, Class Loss: 0.2494, Accuracy: 0.0864
# Epoch [6/4000], Discriminator Loss: 0.0962, Generator Loss: 0.0961, Series Loss: 0.0245, Class Loss: 0.2494, Accuracy: 0.0926
# Epoch [7/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0955, Series Loss: 0.0240, Class Loss: 0.2493, Accuracy: 0.1049
# Epoch [8/4000], Discriminator Loss: 0.0958, Generator Loss: 0.0950, Series Loss: 0.0237, Class Loss: 0.2492, Accuracy: 0.1111
# Epoch [9/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0947, Series Loss: 0.0233, Class Loss: 0.2493, Accuracy: 0.0926
# Epoch [10/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0943, Series Loss: 0.0230, Class Loss: 0.2492, Accuracy: 0.0926
# Epoch [11/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0941, Series Loss: 0.0227, Class Loss: 0.2494, Accuracy: 0.0988
# Epoch [12/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0937, Series Loss: 0.0224, Class Loss: 0.2492, Accuracy: 0.0988
# Epoch [13/4000], Discriminator Loss: 0.0955, Generator Loss: 0.0934, Series Loss: 0.0219, Class Loss: 0.2492, Accuracy: 0.1235
# Epoch [14/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0930, Series Loss: 0.0217, Class Loss: 0.2492, Accuracy: 0.1173
# Epoch [15/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0928, Series Loss: 0.0214, Class Loss: 0.2491, Accuracy: 0.1111
# Epoch [16/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0923, Series Loss: 0.0210, Class Loss: 0.2491, Accuracy: 0.1049
# Epoch [17/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0923, Series Loss: 0.0208, Class Loss: 0.2490, Accuracy: 0.1420
# Epoch [18/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0922, Series Loss: 0.0204, Class Loss: 0.2491, Accuracy: 0.1420
# Epoch [19/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0916, Series Loss: 0.0201, Class Loss: 0.2492, Accuracy: 0.1296
# Epoch [20/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0912, Series Loss: 0.0198, Class Loss: 0.2490, Accuracy: 0.1358
# Epoch [21/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0912, Series Loss: 0.0196, Class Loss: 0.2491, Accuracy: 0.1173
# Epoch [22/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0905, Series Loss: 0.0192, Class Loss: 0.2490, Accuracy: 0.1173
# Epoch [23/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0904, Series Loss: 0.0189, Class Loss: 0.2489, Accuracy: 0.1173
# Epoch [24/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0898, Series Loss: 0.0186, Class Loss: 0.2490, Accuracy: 0.1173
# Epoch [25/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0898, Series Loss: 0.0184, Class Loss: 0.2490, Accuracy: 0.1111
# Epoch [26/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0894, Series Loss: 0.0180, Class Loss: 0.2490, Accuracy: 0.0926
# Epoch [27/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0891, Series Loss: 0.0177, Class Loss: 0.2492, Accuracy: 0.0926
# Epoch [28/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0890, Series Loss: 0.0176, Class Loss: 0.2489, Accuracy: 0.1111
# Epoch [29/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0884, Series Loss: 0.0173, Class Loss: 0.2487, Accuracy: 0.1049
# Epoch [30/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0884, Series Loss: 0.0170, Class Loss: 0.2488, Accuracy: 0.0988
# Epoch [31/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0879, Series Loss: 0.0166, Class Loss: 0.2489, Accuracy: 0.1049
# Epoch [32/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0877, Series Loss: 0.0164, Class Loss: 0.2487, Accuracy: 0.0926
# Epoch [33/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0874, Series Loss: 0.0162, Class Loss: 0.2489, Accuracy: 0.0864
# Epoch [34/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0871, Series Loss: 0.0158, Class Loss: 0.2489, Accuracy: 0.1049
# Epoch [35/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0871, Series Loss: 0.0158, Class Loss: 0.2487, Accuracy: 0.1111
# Epoch [36/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0869, Series Loss: 0.0155, Class Loss: 0.2488, Accuracy: 0.0926
# Epoch [37/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0864, Series Loss: 0.0152, Class Loss: 0.2488, Accuracy: 0.0988
# Epoch [38/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0861, Series Loss: 0.0149, Class Loss: 0.2489, Accuracy: 0.1111
# Epoch [39/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0857, Series Loss: 0.0147, Class Loss: 0.2487, Accuracy: 0.0926
# Epoch [40/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0855, Series Loss: 0.0143, Class Loss: 0.2486, Accuracy: 0.0864
# Epoch [41/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0853, Series Loss: 0.0142, Class Loss: 0.2487, Accuracy: 0.0864
# Epoch [42/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0853, Series Loss: 0.0139, Class Loss: 0.2487, Accuracy: 0.0802
# Epoch [43/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0847, Series Loss: 0.0136, Class Loss: 0.2488, Accuracy: 0.0926
# Epoch [44/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0846, Series Loss: 0.0134, Class Loss: 0.2488, Accuracy: 0.0988
# Epoch [45/4000], Discriminator Loss: 0.0957, Generator Loss: 0.0842, Series Loss: 0.0132, Class Loss: 0.2488, Accuracy: 0.0802
# Epoch [46/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0843, Series Loss: 0.0130, Class Loss: 0.2488, Accuracy: 0.1111
# Epoch [47/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0837, Series Loss: 0.0127, Class Loss: 0.2486, Accuracy: 0.0926
# Epoch [48/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0834, Series Loss: 0.0125, Class Loss: 0.2487, Accuracy: 0.0926
# Epoch [49/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0832, Series Loss: 0.0123, Class Loss: 0.2487, Accuracy: 0.0864
# Epoch [50/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0831, Series Loss: 0.0121, Class Loss: 0.2485, Accuracy: 0.1049
# Epoch [51/4000], Discriminator Loss: 0.0958, Generator Loss: 0.0827, Series Loss: 0.0118, Class Loss: 0.2486, Accuracy: 0.0926
# Epoch [52/4000], Discriminator Loss: 0.0957, Generator Loss: 0.0826, Series Loss: 0.0116, Class Loss: 0.2486, Accuracy: 0.0679
# Epoch [53/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0824, Series Loss: 0.0114, Class Loss: 0.2485, Accuracy: 0.0988
# Epoch [54/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0820, Series Loss: 0.0111, Class Loss: 0.2484, Accuracy: 0.0926
# Epoch [55/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0819, Series Loss: 0.0109, Class Loss: 0.2486, Accuracy: 0.0802
# Epoch [56/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0815, Series Loss: 0.0107, Class Loss: 0.2486, Accuracy: 0.0679
# Epoch [57/4000], Discriminator Loss: 0.0955, Generator Loss: 0.0813, Series Loss: 0.0106, Class Loss: 0.2485, Accuracy: 0.0802
# Epoch [58/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0811, Series Loss: 0.0103, Class Loss: 0.2484, Accuracy: 0.1049
# Epoch [59/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0810, Series Loss: 0.0101, Class Loss: 0.2485, Accuracy: 0.0988
# Epoch [60/4000], Discriminator Loss: 0.0955, Generator Loss: 0.0808, Series Loss: 0.0099, Class Loss: 0.2486, Accuracy: 0.0864
# Epoch [61/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0807, Series Loss: 0.0097, Class Loss: 0.2485, Accuracy: 0.0802
# Epoch [62/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0806, Series Loss: 0.0095, Class Loss: 0.2485, Accuracy: 0.0741
# Epoch [63/4000], Discriminator Loss: 0.0961, Generator Loss: 0.0805, Series Loss: 0.0094, Class Loss: 0.2486, Accuracy: 0.0802
# Epoch [64/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0802, Series Loss: 0.0092, Class Loss: 0.2485, Accuracy: 0.0988
# Epoch [65/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0797, Series Loss: 0.0089, Class Loss: 0.2485, Accuracy: 0.0926
# Epoch [66/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0801, Series Loss: 0.0088, Class Loss: 0.2484, Accuracy: 0.0926
# Epoch [67/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0796, Series Loss: 0.0086, Class Loss: 0.2484, Accuracy: 0.0988
# Epoch [68/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0795, Series Loss: 0.0085, Class Loss: 0.2483, Accuracy: 0.1049
# Epoch [69/4000], Discriminator Loss: 0.0955, Generator Loss: 0.0794, Series Loss: 0.0084, Class Loss: 0.2484, Accuracy: 0.0988
# Epoch [70/4000], Discriminator Loss: 0.0949, Generator Loss: 0.0792, Series Loss: 0.0082, Class Loss: 0.2483, Accuracy: 0.0802
# Epoch [71/4000], Discriminator Loss: 0.0951, Generator Loss: 0.0792, Series Loss: 0.0080, Class Loss: 0.2483, Accuracy: 0.0864
# Epoch [72/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0791, Series Loss: 0.0079, Class Loss: 0.2483, Accuracy: 0.0926
# Epoch [73/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0788, Series Loss: 0.0078, Class Loss: 0.2483, Accuracy: 0.0864
# Epoch [74/4000], Discriminator Loss: 0.0953, Generator Loss: 0.0788, Series Loss: 0.0076, Class Loss: 0.2482, Accuracy: 0.0679
# Epoch [75/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0785, Series Loss: 0.0075, Class Loss: 0.2482, Accuracy: 0.1049
# Epoch [76/4000], Discriminator Loss: 0.0950, Generator Loss: 0.0786, Series Loss: 0.0075, Class Loss: 0.2484, Accuracy: 0.0802
# Epoch [77/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0786, Series Loss: 0.0074, Class Loss: 0.2481, Accuracy: 0.1111
# Epoch [78/4000], Discriminator Loss: 0.0948, Generator Loss: 0.0784, Series Loss: 0.0072, Class Loss: 0.2482, Accuracy: 0.0988
# Epoch [79/4000], Discriminator Loss: 0.0946, Generator Loss: 0.0782, Series Loss: 0.0070, Class Loss: 0.2482, Accuracy: 0.0926
# Epoch [80/4000], Discriminator Loss: 0.0948, Generator Loss: 0.0782, Series Loss: 0.0069, Class Loss: 0.2482, Accuracy: 0.0926
# Epoch [81/4000], Discriminator Loss: 0.0952, Generator Loss: 0.0782, Series Loss: 0.0068, Class Loss: 0.2482, Accuracy: 0.0926
# Epoch [82/4000], Discriminator Loss: 0.0947, Generator Loss: 0.0780, Series Loss: 0.0068, Class Loss: 0.2481, Accuracy: 0.1049
# Epoch [83/4000], Discriminator Loss: 0.0942, Generator Loss: 0.0779, Series Loss: 0.0067, Class Loss: 0.2482, Accuracy: 0.1173
# Epoch [84/4000], Discriminator Loss: 0.0948, Generator Loss: 0.0779, Series Loss: 0.0066, Class Loss: 0.2481, Accuracy: 0.1235
# Epoch [85/4000], Discriminator Loss: 0.0948, Generator Loss: 0.0778, Series Loss: 0.0065, Class Loss: 0.2481, Accuracy: 0.1049
# Epoch [86/4000], Discriminator Loss: 0.0945, Generator Loss: 0.0777, Series Loss: 0.0064, Class Loss: 0.2481, Accuracy: 0.0864
# Epoch [87/4000], Discriminator Loss: 0.0944, Generator Loss: 0.0775, Series Loss: 0.0063, Class Loss: 0.2481, Accuracy: 0.1235
# Epoch [88/4000], Discriminator Loss: 0.0944, Generator Loss: 0.0774, Series Loss: 0.0062, Class Loss: 0.2480, Accuracy: 0.1296
# Epoch [89/4000], Discriminator Loss: 0.0941, Generator Loss: 0.0775, Series Loss: 0.0061, Class Loss: 0.2480, Accuracy: 0.0864
# Epoch [90/4000], Discriminator Loss: 0.0942, Generator Loss: 0.0775, Series Loss: 0.0060, Class Loss: 0.2479, Accuracy: 0.1049
# Epoch [91/4000], Discriminator Loss: 0.0944, Generator Loss: 0.0773, Series Loss: 0.0060, Class Loss: 0.2479, Accuracy: 0.1111
# Epoch [92/4000], Discriminator Loss: 0.0942, Generator Loss: 0.0774, Series Loss: 0.0059, Class Loss: 0.2479, Accuracy: 0.1235
# Epoch [93/4000], Discriminator Loss: 0.0941, Generator Loss: 0.0774, Series Loss: 0.0058, Class Loss: 0.2478, Accuracy: 0.1235
# Epoch [94/4000], Discriminator Loss: 0.0942, Generator Loss: 0.0773, Series Loss: 0.0058, Class Loss: 0.2477, Accuracy: 0.1235
# Epoch [95/4000], Discriminator Loss: 0.0936, Generator Loss: 0.0773, Series Loss: 0.0057, Class Loss: 0.2479, Accuracy: 0.1049
# Epoch [96/4000], Discriminator Loss: 0.0939, Generator Loss: 0.0771, Series Loss: 0.0056, Class Loss: 0.2478, Accuracy: 0.1173
# Epoch [97/4000], Discriminator Loss: 0.0940, Generator Loss: 0.0772, Series Loss: 0.0056, Class Loss: 0.2479, Accuracy: 0.1049
# Epoch [98/4000], Discriminator Loss: 0.0939, Generator Loss: 0.0770, Series Loss: 0.0055, Class Loss: 0.2479, Accuracy: 0.1111
# Epoch [99/4000], Discriminator Loss: 0.0940, Generator Loss: 0.0770, Series Loss: 0.0055, Class Loss: 0.2477, Accuracy: 0.1111
# Epoch [100/4000], Discriminator Loss: 0.0938, Generator Loss: 0.0770, Series Loss: 0.0054, Class Loss: 0.2477, Accuracy: 0.1296
# Epoch [101/4000], Discriminator Loss: 0.0940, Generator Loss: 0.0769, Series Loss: 0.0053, Class Loss: 0.2476, Accuracy: 0.1358
# Epoch [102/4000], Discriminator Loss: 0.0937, Generator Loss: 0.0768, Series Loss: 0.0052, Class Loss: 0.2477, Accuracy: 0.1173
# Epoch [103/4000], Discriminator Loss: 0.0938, Generator Loss: 0.0769, Series Loss: 0.0052, Class Loss: 0.2475, Accuracy: 0.1235
# Epoch [104/4000], Discriminator Loss: 0.0937, Generator Loss: 0.0768, Series Loss: 0.0051, Class Loss: 0.2476, Accuracy: 0.1358
# Epoch [105/4000], Discriminator Loss: 0.0934, Generator Loss: 0.0767, Series Loss: 0.0051, Class Loss: 0.2475, Accuracy: 0.1235
# Epoch [106/4000], Discriminator Loss: 0.0936, Generator Loss: 0.0768, Series Loss: 0.0050, Class Loss: 0.2475, Accuracy: 0.1358
# Epoch [107/4000], Discriminator Loss: 0.0936, Generator Loss: 0.0768, Series Loss: 0.0050, Class Loss: 0.2477, Accuracy: 0.1235
# Epoch [108/4000], Discriminator Loss: 0.0935, Generator Loss: 0.0767, Series Loss: 0.0049, Class Loss: 0.2475, Accuracy: 0.1235
# Epoch [109/4000], Discriminator Loss: 0.0938, Generator Loss: 0.0766, Series Loss: 0.0049, Class Loss: 0.2475, Accuracy: 0.1296
# Epoch [110/4000], Discriminator Loss: 0.0930, Generator Loss: 0.0766, Series Loss: 0.0048, Class Loss: 0.2475, Accuracy: 0.1235
# Epoch [111/4000], Discriminator Loss: 0.0933, Generator Loss: 0.0763, Series Loss: 0.0048, Class Loss: 0.2475, Accuracy: 0.1111
# Epoch [112/4000], Discriminator Loss: 0.0935, Generator Loss: 0.0765, Series Loss: 0.0047, Class Loss: 0.2476, Accuracy: 0.1420
# Epoch [113/4000], Discriminator Loss: 0.0932, Generator Loss: 0.0765, Series Loss: 0.0047, Class Loss: 0.2475, Accuracy: 0.1481
# Epoch [114/4000], Discriminator Loss: 0.0934, Generator Loss: 0.0762, Series Loss: 0.0046, Class Loss: 0.2474, Accuracy: 0.1111
# Epoch [115/4000], Discriminator Loss: 0.0933, Generator Loss: 0.0762, Series Loss: 0.0046, Class Loss: 0.2474, Accuracy: 0.1296
# Epoch [116/4000], Discriminator Loss: 0.0931, Generator Loss: 0.0764, Series Loss: 0.0046, Class Loss: 0.2474, Accuracy: 0.1235
# Epoch [117/4000], Discriminator Loss: 0.0931, Generator Loss: 0.0762, Series Loss: 0.0045, Class Loss: 0.2472, Accuracy: 0.1481
# Epoch [118/4000], Discriminator Loss: 0.0929, Generator Loss: 0.0762, Series Loss: 0.0044, Class Loss: 0.2475, Accuracy: 0.1605
# Epoch [119/4000], Discriminator Loss: 0.0927, Generator Loss: 0.0762, Series Loss: 0.0044, Class Loss: 0.2474, Accuracy: 0.1420
# Epoch [120/4000], Discriminator Loss: 0.0926, Generator Loss: 0.0762, Series Loss: 0.0044, Class Loss: 0.2471, Accuracy: 0.1543
# Epoch [121/4000], Discriminator Loss: 0.0925, Generator Loss: 0.0763, Series Loss: 0.0043, Class Loss: 0.2473, Accuracy: 0.1481
# Epoch [122/4000], Discriminator Loss: 0.0927, Generator Loss: 0.0762, Series Loss: 0.0043, Class Loss: 0.2472, Accuracy: 0.1420
# Epoch [123/4000], Discriminator Loss: 0.0927, Generator Loss: 0.0761, Series Loss: 0.0043, Class Loss: 0.2473, Accuracy: 0.1605
# Epoch [124/4000], Discriminator Loss: 0.0926, Generator Loss: 0.0761, Series Loss: 0.0042, Class Loss: 0.2474, Accuracy: 0.1358
# Epoch [125/4000], Discriminator Loss: 0.0925, Generator Loss: 0.0761, Series Loss: 0.0042, Class Loss: 0.2472, Accuracy: 0.1667
# Epoch [126/4000], Discriminator Loss: 0.0929, Generator Loss: 0.0759, Series Loss: 0.0041, Class Loss: 0.2471, Accuracy: 0.1790
# Epoch [127/4000], Discriminator Loss: 0.0929, Generator Loss: 0.0760, Series Loss: 0.0041, Class Loss: 0.2473, Accuracy: 0.1852
# Epoch [128/4000], Discriminator Loss: 0.0921, Generator Loss: 0.0758, Series Loss: 0.0041, Class Loss: 0.2471, Accuracy: 0.1667
# Epoch [129/4000], Discriminator Loss: 0.0926, Generator Loss: 0.0760, Series Loss: 0.0041, Class Loss: 0.2471, Accuracy: 0.1914
# Epoch [130/4000], Discriminator Loss: 0.0923, Generator Loss: 0.0760, Series Loss: 0.0040, Class Loss: 0.2472, Accuracy: 0.2160
# Epoch [131/4000], Discriminator Loss: 0.0925, Generator Loss: 0.0759, Series Loss: 0.0040, Class Loss: 0.2471, Accuracy: 0.2222
# Epoch [132/4000], Discriminator Loss: 0.0923, Generator Loss: 0.0760, Series Loss: 0.0040, Class Loss: 0.2469, Accuracy: 0.2160
# Epoch [133/4000], Discriminator Loss: 0.0925, Generator Loss: 0.0760, Series Loss: 0.0040, Class Loss: 0.2470, Accuracy: 0.2160
# Epoch [134/4000], Discriminator Loss: 0.0921, Generator Loss: 0.0758, Series Loss: 0.0039, Class Loss: 0.2470, Accuracy: 0.2531
# Epoch [135/4000], Discriminator Loss: 0.0920, Generator Loss: 0.0759, Series Loss: 0.0039, Class Loss: 0.2470, Accuracy: 0.2716
# Epoch [136/4000], Discriminator Loss: 0.0922, Generator Loss: 0.0758, Series Loss: 0.0039, Class Loss: 0.2470, Accuracy: 0.2716
# Epoch [137/4000], Discriminator Loss: 0.0922, Generator Loss: 0.0756, Series Loss: 0.0038, Class Loss: 0.2470, Accuracy: 0.2840
# Epoch [138/4000], Discriminator Loss: 0.0919, Generator Loss: 0.0758, Series Loss: 0.0038, Class Loss: 0.2470, Accuracy: 0.3025
# Epoch [139/4000], Discriminator Loss: 0.0921, Generator Loss: 0.0758, Series Loss: 0.0038, Class Loss: 0.2470, Accuracy: 0.3272
# Epoch [140/4000], Discriminator Loss: 0.0921, Generator Loss: 0.0758, Series Loss: 0.0037, Class Loss: 0.2470, Accuracy: 0.3704
# Epoch [141/4000], Discriminator Loss: 0.0918, Generator Loss: 0.0757, Series Loss: 0.0037, Class Loss: 0.2470, Accuracy: 0.3704
# Epoch [142/4000], Discriminator Loss: 0.0919, Generator Loss: 0.0758, Series Loss: 0.0037, Class Loss: 0.2467, Accuracy: 0.3889
# Epoch [143/4000], Discriminator Loss: 0.0920, Generator Loss: 0.0757, Series Loss: 0.0036, Class Loss: 0.2467, Accuracy: 0.3704
# Epoch [144/4000], Discriminator Loss: 0.0920, Generator Loss: 0.0757, Series Loss: 0.0036, Class Loss: 0.2467, Accuracy: 0.4321
# Epoch [145/4000], Discriminator Loss: 0.0917, Generator Loss: 0.0756, Series Loss: 0.0036, Class Loss: 0.2468, Accuracy: 0.4012
# Epoch [146/4000], Discriminator Loss: 0.0919, Generator Loss: 0.0757, Series Loss: 0.0036, Class Loss: 0.2469, Accuracy: 0.4383
# Epoch [147/4000], Discriminator Loss: 0.0919, Generator Loss: 0.0756, Series Loss: 0.0035, Class Loss: 0.2469, Accuracy: 0.4506
# Epoch [148/4000], Discriminator Loss: 0.0917, Generator Loss: 0.0757, Series Loss: 0.0035, Class Loss: 0.2469, Accuracy: 0.4506
# Epoch [149/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0756, Series Loss: 0.0035, Class Loss: 0.2468, Accuracy: 0.4444
# Epoch [150/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0756, Series Loss: 0.0035, Class Loss: 0.2467, Accuracy: 0.4568
# Epoch [151/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0755, Series Loss: 0.0035, Class Loss: 0.2468, Accuracy: 0.4938
# Epoch [152/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0755, Series Loss: 0.0034, Class Loss: 0.2467, Accuracy: 0.4753
# Epoch [153/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0754, Series Loss: 0.0034, Class Loss: 0.2467, Accuracy: 0.4938
# Epoch [154/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0754, Series Loss: 0.0034, Class Loss: 0.2468, Accuracy: 0.5000
# Epoch [155/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0755, Series Loss: 0.0033, Class Loss: 0.2466, Accuracy: 0.4630
# Epoch [156/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0754, Series Loss: 0.0033, Class Loss: 0.2466, Accuracy: 0.5062
# Epoch [157/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0754, Series Loss: 0.0033, Class Loss: 0.2467, Accuracy: 0.5926
# Epoch [158/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0754, Series Loss: 0.0033, Class Loss: 0.2466, Accuracy: 0.5802
# Epoch [159/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0754, Series Loss: 0.0032, Class Loss: 0.2467, Accuracy: 0.5679
# Epoch [160/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0754, Series Loss: 0.0032, Class Loss: 0.2465, Accuracy: 0.5617
# Epoch [161/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0754, Series Loss: 0.0032, Class Loss: 0.2466, Accuracy: 0.5741
# Epoch [162/4000], Discriminator Loss: 0.0912, Generator Loss: 0.0753, Series Loss: 0.0032, Class Loss: 0.2465, Accuracy: 0.5988
# Epoch [163/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0753, Series Loss: 0.0032, Class Loss: 0.2464, Accuracy: 0.5494
# Epoch [164/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0753, Series Loss: 0.0032, Class Loss: 0.2464, Accuracy: 0.6543
# Epoch [165/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0753, Series Loss: 0.0031, Class Loss: 0.2464, Accuracy: 0.5802
# Epoch [166/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0753, Series Loss: 0.0031, Class Loss: 0.2466, Accuracy: 0.5802
# Epoch [167/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0753, Series Loss: 0.0031, Class Loss: 0.2466, Accuracy: 0.6049
# Epoch [168/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0753, Series Loss: 0.0031, Class Loss: 0.2464, Accuracy: 0.6358
# Epoch [169/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0753, Series Loss: 0.0030, Class Loss: 0.2466, Accuracy: 0.6543
# Epoch [170/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0753, Series Loss: 0.0030, Class Loss: 0.2465, Accuracy: 0.6296
# Epoch [171/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0752, Series Loss: 0.0030, Class Loss: 0.2464, Accuracy: 0.6296
# Epoch [172/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0752, Series Loss: 0.0030, Class Loss: 0.2463, Accuracy: 0.6173
# Epoch [173/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0751, Series Loss: 0.0029, Class Loss: 0.2463, Accuracy: 0.6543
# Epoch [174/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0752, Series Loss: 0.0030, Class Loss: 0.2464, Accuracy: 0.6358
# Epoch [175/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0752, Series Loss: 0.0030, Class Loss: 0.2464, Accuracy: 0.6235
# Epoch [176/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0751, Series Loss: 0.0029, Class Loss: 0.2461, Accuracy: 0.6173
# Epoch [177/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0751, Series Loss: 0.0029, Class Loss: 0.2465, Accuracy: 0.5988
# Epoch [178/4000], Discriminator Loss: 0.0907, Generator Loss: 0.0751, Series Loss: 0.0029, Class Loss: 0.2464, Accuracy: 0.6235
# Epoch [179/4000], Discriminator Loss: 0.0906, Generator Loss: 0.0751, Series Loss: 0.0028, Class Loss: 0.2465, Accuracy: 0.6296
# Epoch [180/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0751, Series Loss: 0.0028, Class Loss: 0.2463, Accuracy: 0.6605
# Epoch [181/4000], Discriminator Loss: 0.0902, Generator Loss: 0.0750, Series Loss: 0.0028, Class Loss: 0.2463, Accuracy: 0.6358
# Epoch [182/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0751, Series Loss: 0.0028, Class Loss: 0.2462, Accuracy: 0.6481
# Epoch [183/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0751, Series Loss: 0.0028, Class Loss: 0.2461, Accuracy: 0.6481
# Epoch [184/4000], Discriminator Loss: 0.0903, Generator Loss: 0.0751, Series Loss: 0.0028, Class Loss: 0.2463, Accuracy: 0.6728
# Epoch [185/4000], Discriminator Loss: 0.0903, Generator Loss: 0.0751, Series Loss: 0.0027, Class Loss: 0.2462, Accuracy: 0.6605
# Epoch [186/4000], Discriminator Loss: 0.0900, Generator Loss: 0.0750, Series Loss: 0.0027, Class Loss: 0.2463, Accuracy: 0.6420
# Epoch [187/4000], Discriminator Loss: 0.0900, Generator Loss: 0.0751, Series Loss: 0.0027, Class Loss: 0.2461, Accuracy: 0.6481
# Epoch [188/4000], Discriminator Loss: 0.0900, Generator Loss: 0.0750, Series Loss: 0.0027, Class Loss: 0.2461, Accuracy: 0.6358
# Epoch [189/4000], Discriminator Loss: 0.0901, Generator Loss: 0.0749, Series Loss: 0.0027, Class Loss: 0.2462, Accuracy: 0.6296
# Epoch [190/4000], Discriminator Loss: 0.0899, Generator Loss: 0.0750, Series Loss: 0.0027, Class Loss: 0.2460, Accuracy: 0.6667
# Epoch [191/4000], Discriminator Loss: 0.0898, Generator Loss: 0.0750, Series Loss: 0.0026, Class Loss: 0.2461, Accuracy: 0.6543
# Epoch [192/4000], Discriminator Loss: 0.0899, Generator Loss: 0.0750, Series Loss: 0.0026, Class Loss: 0.2460, Accuracy: 0.6728
# Epoch [193/4000], Discriminator Loss: 0.0899, Generator Loss: 0.0749, Series Loss: 0.0026, Class Loss: 0.2460, Accuracy: 0.6852
# Epoch [194/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0749, Series Loss: 0.0026, Class Loss: 0.2460, Accuracy: 0.6667
# Epoch [195/4000], Discriminator Loss: 0.0897, Generator Loss: 0.0750, Series Loss: 0.0026, Class Loss: 0.2461, Accuracy: 0.6358
# Epoch [196/4000], Discriminator Loss: 0.0898, Generator Loss: 0.0750, Series Loss: 0.0026, Class Loss: 0.2459, Accuracy: 0.6358
# Epoch [197/4000], Discriminator Loss: 0.0899, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6420
# Epoch [198/4000], Discriminator Loss: 0.0897, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6914
# Epoch [199/4000], Discriminator Loss: 0.0896, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2461, Accuracy: 0.6481
# Epoch [200/4000], Discriminator Loss: 0.0901, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6605
# Epoch [201/4000], Discriminator Loss: 0.0898, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6605
# Epoch [202/4000], Discriminator Loss: 0.0897, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6790
# Epoch [203/4000], Discriminator Loss: 0.0897, Generator Loss: 0.0749, Series Loss: 0.0025, Class Loss: 0.2460, Accuracy: 0.6543
# Epoch [204/4000], Discriminator Loss: 0.0895, Generator Loss: 0.0749, Series Loss: 0.0024, Class Loss: 0.2460, Accuracy: 0.6358
# Epoch [205/4000], Discriminator Loss: 0.0895, Generator Loss: 0.0749, Series Loss: 0.0024, Class Loss: 0.2459, Accuracy: 0.6296
# Epoch [206/4000], Discriminator Loss: 0.0894, Generator Loss: 0.0749, Series Loss: 0.0024, Class Loss: 0.2460, Accuracy: 0.6852
# Epoch [207/4000], Discriminator Loss: 0.0894, Generator Loss: 0.0750, Series Loss: 0.0024, Class Loss: 0.2459, Accuracy: 0.6049
# Epoch [208/4000], Discriminator Loss: 0.0895, Generator Loss: 0.0748, Series Loss: 0.0024, Class Loss: 0.2460, Accuracy: 0.6481
# Epoch [209/4000], Discriminator Loss: 0.0894, Generator Loss: 0.0750, Series Loss: 0.0024, Class Loss: 0.2457, Accuracy: 0.6173
# Epoch [210/4000], Discriminator Loss: 0.0896, Generator Loss: 0.0749, Series Loss: 0.0024, Class Loss: 0.2459, Accuracy: 0.6235
# Epoch [211/4000], Discriminator Loss: 0.0892, Generator Loss: 0.0749, Series Loss: 0.0024, Class Loss: 0.2458, Accuracy: 0.6296
# Epoch [212/4000], Discriminator Loss: 0.0895, Generator Loss: 0.0748, Series Loss: 0.0024, Class Loss: 0.2457, Accuracy: 0.6481
# Epoch [213/4000], Discriminator Loss: 0.0890, Generator Loss: 0.0749, Series Loss: 0.0023, Class Loss: 0.2459, Accuracy: 0.6235
# Epoch [214/4000], Discriminator Loss: 0.0896, Generator Loss: 0.0748, Series Loss: 0.0023, Class Loss: 0.2459, Accuracy: 0.6481
# Epoch [215/4000], Discriminator Loss: 0.0892, Generator Loss: 0.0748, Series Loss: 0.0023, Class Loss: 0.2458, Accuracy: 0.6605
# Epoch [216/4000], Discriminator Loss: 0.0887, Generator Loss: 0.0749, Series Loss: 0.0023, Class Loss: 0.2458, Accuracy: 0.6420
# Epoch [217/4000], Discriminator Loss: 0.0892, Generator Loss: 0.0749, Series Loss: 0.0023, Class Loss: 0.2459, Accuracy: 0.6543
# Epoch [218/4000], Discriminator Loss: 0.0889, Generator Loss: 0.0749, Series Loss: 0.0023, Class Loss: 0.2458, Accuracy: 0.6173
# Epoch [219/4000], Discriminator Loss: 0.0888, Generator Loss: 0.0750, Series Loss: 0.0023, Class Loss: 0.2458, Accuracy: 0.6296
# Epoch [220/4000], Discriminator Loss: 0.0891, Generator Loss: 0.0750, Series Loss: 0.0023, Class Loss: 0.2456, Accuracy: 0.6481
# Epoch [221/4000], Discriminator Loss: 0.0887, Generator Loss: 0.0750, Series Loss: 0.0022, Class Loss: 0.2457, Accuracy: 0.6481
# Epoch [222/4000], Discriminator Loss: 0.0889, Generator Loss: 0.0749, Series Loss: 0.0022, Class Loss: 0.2457, Accuracy: 0.6728
# Epoch [223/4000], Discriminator Loss: 0.0884, Generator Loss: 0.0749, Series Loss: 0.0022, Class Loss: 0.2458, Accuracy: 0.6481
# Epoch [224/4000], Discriminator Loss: 0.0889, Generator Loss: 0.0750, Series Loss: 0.0022, Class Loss: 0.2456, Accuracy: 0.6111
# Epoch [225/4000], Discriminator Loss: 0.0887, Generator Loss: 0.0749, Series Loss: 0.0022, Class Loss: 0.2457, Accuracy: 0.6543
# Epoch [226/4000], Discriminator Loss: 0.0885, Generator Loss: 0.0750, Series Loss: 0.0022, Class Loss: 0.2457, Accuracy: 0.5864
# Epoch [227/4000], Discriminator Loss: 0.0885, Generator Loss: 0.0750, Series Loss: 0.0022, Class Loss: 0.2457, Accuracy: 0.6358
# Epoch [228/4000], Discriminator Loss: 0.0885, Generator Loss: 0.0750, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.6481
# Epoch [229/4000], Discriminator Loss: 0.0886, Generator Loss: 0.0751, Series Loss: 0.0022, Class Loss: 0.2456, Accuracy: 0.6049
# Epoch [230/4000], Discriminator Loss: 0.0885, Generator Loss: 0.0750, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.5556
# Epoch [231/4000], Discriminator Loss: 0.0886, Generator Loss: 0.0749, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.6358
# Epoch [232/4000], Discriminator Loss: 0.0882, Generator Loss: 0.0751, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.5988
# Epoch [233/4000], Discriminator Loss: 0.0882, Generator Loss: 0.0751, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.6543
# Epoch [234/4000], Discriminator Loss: 0.0881, Generator Loss: 0.0752, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.6358
# Epoch [235/4000], Discriminator Loss: 0.0880, Generator Loss: 0.0753, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.6296
# Epoch [236/4000], Discriminator Loss: 0.0885, Generator Loss: 0.0751, Series Loss: 0.0021, Class Loss: 0.2457, Accuracy: 0.6111
# Epoch [237/4000], Discriminator Loss: 0.0880, Generator Loss: 0.0752, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5926
# Epoch [238/4000], Discriminator Loss: 0.0876, Generator Loss: 0.0754, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.6235
# Epoch [239/4000], Discriminator Loss: 0.0880, Generator Loss: 0.0753, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.5741
# Epoch [240/4000], Discriminator Loss: 0.0879, Generator Loss: 0.0753, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5247
# Epoch [241/4000], Discriminator Loss: 0.0881, Generator Loss: 0.0753, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.6111
# Epoch [242/4000], Discriminator Loss: 0.0879, Generator Loss: 0.0752, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.5617
# Epoch [243/4000], Discriminator Loss: 0.0881, Generator Loss: 0.0754, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5741
# Epoch [244/4000], Discriminator Loss: 0.0882, Generator Loss: 0.0753, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.5309
# Epoch [245/4000], Discriminator Loss: 0.0878, Generator Loss: 0.0755, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5370
# Epoch [246/4000], Discriminator Loss: 0.0878, Generator Loss: 0.0754, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5247
# Epoch [247/4000], Discriminator Loss: 0.0874, Generator Loss: 0.0755, Series Loss: 0.0020, Class Loss: 0.2455, Accuracy: 0.5309
# Epoch [248/4000], Discriminator Loss: 0.0876, Generator Loss: 0.0755, Series Loss: 0.0020, Class Loss: 0.2455, Accuracy: 0.5247
# Epoch [249/4000], Discriminator Loss: 0.0874, Generator Loss: 0.0756, Series Loss: 0.0020, Class Loss: 0.2455, Accuracy: 0.5679
# Epoch [250/4000], Discriminator Loss: 0.0875, Generator Loss: 0.0757, Series Loss: 0.0020, Class Loss: 0.2454, Accuracy: 0.4938
# Epoch [251/4000], Discriminator Loss: 0.0875, Generator Loss: 0.0757, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.5309
# Epoch [252/4000], Discriminator Loss: 0.0870, Generator Loss: 0.0759, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.4815
# Epoch [253/4000], Discriminator Loss: 0.0873, Generator Loss: 0.0758, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.5309
# Epoch [254/4000], Discriminator Loss: 0.0876, Generator Loss: 0.0758, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.5123
# Epoch [255/4000], Discriminator Loss: 0.0868, Generator Loss: 0.0757, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.4630
# Epoch [256/4000], Discriminator Loss: 0.0873, Generator Loss: 0.0759, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.4568
# Epoch [257/4000], Discriminator Loss: 0.0870, Generator Loss: 0.0760, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.4506
# Epoch [258/4000], Discriminator Loss: 0.0869, Generator Loss: 0.0758, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4444
# Epoch [259/4000], Discriminator Loss: 0.0871, Generator Loss: 0.0761, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4691
# Epoch [260/4000], Discriminator Loss: 0.0869, Generator Loss: 0.0760, Series Loss: 0.0021, Class Loss: 0.2453, Accuracy: 0.4938
# Epoch [261/4000], Discriminator Loss: 0.0869, Generator Loss: 0.0760, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4198
# Epoch [262/4000], Discriminator Loss: 0.0867, Generator Loss: 0.0760, Series Loss: 0.0021, Class Loss: 0.2453, Accuracy: 0.5062
# Epoch [263/4000], Discriminator Loss: 0.0863, Generator Loss: 0.0761, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4877
# Epoch [264/4000], Discriminator Loss: 0.0863, Generator Loss: 0.0762, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.4506
# Epoch [265/4000], Discriminator Loss: 0.0864, Generator Loss: 0.0763, Series Loss: 0.0021, Class Loss: 0.2453, Accuracy: 0.4691
# Epoch [266/4000], Discriminator Loss: 0.0867, Generator Loss: 0.0765, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4198
# Epoch [267/4000], Discriminator Loss: 0.0866, Generator Loss: 0.0763, Series Loss: 0.0021, Class Loss: 0.2455, Accuracy: 0.3951
# Epoch [268/4000], Discriminator Loss: 0.0865, Generator Loss: 0.0765, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.4259
# Epoch [269/4000], Discriminator Loss: 0.0864, Generator Loss: 0.0765, Series Loss: 0.0021, Class Loss: 0.2453, Accuracy: 0.3765
# Epoch [270/4000], Discriminator Loss: 0.0865, Generator Loss: 0.0765, Series Loss: 0.0021, Class Loss: 0.2456, Accuracy: 0.3889
# Epoch [271/4000], Discriminator Loss: 0.0864, Generator Loss: 0.0770, Series Loss: 0.0021, Class Loss: 0.2454, Accuracy: 0.3827
# Epoch [272/4000], Discriminator Loss: 0.0867, Generator Loss: 0.0767, Series Loss: 0.0022, Class Loss: 0.2454, Accuracy: 0.3765
# Epoch [273/4000], Discriminator Loss: 0.0863, Generator Loss: 0.0765, Series Loss: 0.0022, Class Loss: 0.2453, Accuracy: 0.3889
# Epoch [274/4000], Discriminator Loss: 0.0862, Generator Loss: 0.0769, Series Loss: 0.0022, Class Loss: 0.2454, Accuracy: 0.3642
# Epoch [275/4000], Discriminator Loss: 0.0861, Generator Loss: 0.0766, Series Loss: 0.0022, Class Loss: 0.2454, Accuracy: 0.3519
# Epoch [276/4000], Discriminator Loss: 0.0859, Generator Loss: 0.0770, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3148
# Epoch [277/4000], Discriminator Loss: 0.0859, Generator Loss: 0.0768, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3395
# Epoch [278/4000], Discriminator Loss: 0.0862, Generator Loss: 0.0768, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3457
# Epoch [279/4000], Discriminator Loss: 0.0863, Generator Loss: 0.0767, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3272
# Epoch [280/4000], Discriminator Loss: 0.0858, Generator Loss: 0.0770, Series Loss: 0.0022, Class Loss: 0.2454, Accuracy: 0.3457
# Epoch [281/4000], Discriminator Loss: 0.0858, Generator Loss: 0.0771, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3086
# Epoch [282/4000], Discriminator Loss: 0.0861, Generator Loss: 0.0770, Series Loss: 0.0022, Class Loss: 0.2455, Accuracy: 0.3086
# Epoch [283/4000], Discriminator Loss: 0.0855, Generator Loss: 0.0773, Series Loss: 0.0023, Class Loss: 0.2455, Accuracy: 0.3457
# Epoch [284/4000], Discriminator Loss: 0.0861, Generator Loss: 0.0772, Series Loss: 0.0023, Class Loss: 0.2455, Accuracy: 0.3148
# Epoch [285/4000], Discriminator Loss: 0.0857, Generator Loss: 0.0773, Series Loss: 0.0023, Class Loss: 0.2456, Accuracy: 0.3210
# Epoch [286/4000], Discriminator Loss: 0.0860, Generator Loss: 0.0772, Series Loss: 0.0023, Class Loss: 0.2455, Accuracy: 0.3272
# Epoch [287/4000], Discriminator Loss: 0.0853, Generator Loss: 0.0775, Series Loss: 0.0023, Class Loss: 0.2455, Accuracy: 0.2963
# Epoch [288/4000], Discriminator Loss: 0.0855, Generator Loss: 0.0775, Series Loss: 0.0023, Class Loss: 0.2454, Accuracy: 0.3210
# Epoch [289/4000], Discriminator Loss: 0.0855, Generator Loss: 0.0775, Series Loss: 0.0023, Class Loss: 0.2455, Accuracy: 0.2840
# Epoch [290/4000], Discriminator Loss: 0.0859, Generator Loss: 0.0774, Series Loss: 0.0024, Class Loss: 0.2455, Accuracy: 0.3333
# Epoch [291/4000], Discriminator Loss: 0.0853, Generator Loss: 0.0776, Series Loss: 0.0024, Class Loss: 0.2454, Accuracy: 0.3272
# Epoch [292/4000], Discriminator Loss: 0.0852, Generator Loss: 0.0777, Series Loss: 0.0024, Class Loss: 0.2455, Accuracy: 0.3272
# Epoch [293/4000], Discriminator Loss: 0.0852, Generator Loss: 0.0774, Series Loss: 0.0024, Class Loss: 0.2455, Accuracy: 0.3086
# Epoch [294/4000], Discriminator Loss: 0.0853, Generator Loss: 0.0778, Series Loss: 0.0024, Class Loss: 0.2454, Accuracy: 0.2901
# Epoch [295/4000], Discriminator Loss: 0.0852, Generator Loss: 0.0778, Series Loss: 0.0024, Class Loss: 0.2456, Accuracy: 0.2963
# Epoch [296/4000], Discriminator Loss: 0.0850, Generator Loss: 0.0780, Series Loss: 0.0024, Class Loss: 0.2456, Accuracy: 0.3333
# Epoch [297/4000], Discriminator Loss: 0.0851, Generator Loss: 0.0782, Series Loss: 0.0024, Class Loss: 0.2455, Accuracy: 0.3210
# Epoch [298/4000], Discriminator Loss: 0.0851, Generator Loss: 0.0780, Series Loss: 0.0024, Class Loss: 0.2455, Accuracy: 0.3086
# Epoch [299/4000], Discriminator Loss: 0.0852, Generator Loss: 0.0782, Series Loss: 0.0025, Class Loss: 0.2456, Accuracy: 0.2716
# Epoch [300/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0783, Series Loss: 0.0025, Class Loss: 0.2457, Accuracy: 0.3025
# Epoch [301/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0780, Series Loss: 0.0025, Class Loss: 0.2455, Accuracy: 0.2593
# Epoch [302/4000], Discriminator Loss: 0.0850, Generator Loss: 0.0783, Series Loss: 0.0025, Class Loss: 0.2456, Accuracy: 0.3025
# Epoch [303/4000], Discriminator Loss: 0.0848, Generator Loss: 0.0781, Series Loss: 0.0025, Class Loss: 0.2456, Accuracy: 0.2901
# Epoch [304/4000], Discriminator Loss: 0.0847, Generator Loss: 0.0785, Series Loss: 0.0025, Class Loss: 0.2457, Accuracy: 0.2716
# Epoch [305/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0782, Series Loss: 0.0025, Class Loss: 0.2455, Accuracy: 0.2593
# Epoch [306/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0784, Series Loss: 0.0026, Class Loss: 0.2455, Accuracy: 0.2531
# Epoch [307/4000], Discriminator Loss: 0.0852, Generator Loss: 0.0786, Series Loss: 0.0026, Class Loss: 0.2455, Accuracy: 0.2469
# Epoch [308/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0786, Series Loss: 0.0026, Class Loss: 0.2456, Accuracy: 0.2840
# Epoch [309/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0787, Series Loss: 0.0026, Class Loss: 0.2458, Accuracy: 0.2778
# Epoch [310/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0788, Series Loss: 0.0027, Class Loss: 0.2456, Accuracy: 0.2654
# Epoch [311/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0789, Series Loss: 0.0027, Class Loss: 0.2457, Accuracy: 0.2469
# Epoch [312/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0787, Series Loss: 0.0027, Class Loss: 0.2456, Accuracy: 0.2593
# Epoch [313/4000], Discriminator Loss: 0.0848, Generator Loss: 0.0789, Series Loss: 0.0027, Class Loss: 0.2457, Accuracy: 0.2531
# Epoch [314/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0793, Series Loss: 0.0028, Class Loss: 0.2457, Accuracy: 0.2716
# Epoch [315/4000], Discriminator Loss: 0.0842, Generator Loss: 0.0788, Series Loss: 0.0028, Class Loss: 0.2457, Accuracy: 0.2346
# Epoch [316/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0792, Series Loss: 0.0028, Class Loss: 0.2458, Accuracy: 0.2716
# Epoch [317/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0791, Series Loss: 0.0028, Class Loss: 0.2456, Accuracy: 0.2346
# Epoch [318/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0794, Series Loss: 0.0028, Class Loss: 0.2457, Accuracy: 0.2531
# Epoch [319/4000], Discriminator Loss: 0.0847, Generator Loss: 0.0790, Series Loss: 0.0029, Class Loss: 0.2459, Accuracy: 0.2531
# Epoch [320/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0793, Series Loss: 0.0029, Class Loss: 0.2458, Accuracy: 0.1975
# Epoch [321/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0793, Series Loss: 0.0029, Class Loss: 0.2460, Accuracy: 0.1975
# Epoch [322/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0793, Series Loss: 0.0030, Class Loss: 0.2458, Accuracy: 0.2222
# Epoch [323/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0794, Series Loss: 0.0029, Class Loss: 0.2458, Accuracy: 0.2284
# Epoch [324/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0792, Series Loss: 0.0030, Class Loss: 0.2457, Accuracy: 0.2099
# Epoch [325/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0793, Series Loss: 0.0031, Class Loss: 0.2457, Accuracy: 0.2284
# Epoch [326/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0790, Series Loss: 0.0031, Class Loss: 0.2458, Accuracy: 0.1914
# Epoch [327/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0792, Series Loss: 0.0031, Class Loss: 0.2459, Accuracy: 0.1914
# Epoch [328/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0793, Series Loss: 0.0031, Class Loss: 0.2457, Accuracy: 0.2222
# Epoch [329/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0797, Series Loss: 0.0031, Class Loss: 0.2459, Accuracy: 0.2037
# Epoch [330/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0796, Series Loss: 0.0032, Class Loss: 0.2459, Accuracy: 0.2407
# Epoch [331/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0797, Series Loss: 0.0032, Class Loss: 0.2460, Accuracy: 0.1852
# Epoch [332/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0799, Series Loss: 0.0032, Class Loss: 0.2459, Accuracy: 0.1975
# Epoch [333/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0796, Series Loss: 0.0033, Class Loss: 0.2461, Accuracy: 0.1914
# Epoch [334/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0798, Series Loss: 0.0033, Class Loss: 0.2460, Accuracy: 0.1728
# Epoch [335/4000], Discriminator Loss: 0.0837, Generator Loss: 0.0800, Series Loss: 0.0033, Class Loss: 0.2460, Accuracy: 0.2037
# Epoch [336/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0798, Series Loss: 0.0033, Class Loss: 0.2462, Accuracy: 0.1852
# Epoch [337/4000], Discriminator Loss: 0.0839, Generator Loss: 0.0800, Series Loss: 0.0034, Class Loss: 0.2460, Accuracy: 0.2222
# Epoch [338/4000], Discriminator Loss: 0.0839, Generator Loss: 0.0800, Series Loss: 0.0034, Class Loss: 0.2460, Accuracy: 0.1975
# Epoch [339/4000], Discriminator Loss: 0.0842, Generator Loss: 0.0801, Series Loss: 0.0034, Class Loss: 0.2462, Accuracy: 0.1790
# Epoch [340/4000], Discriminator Loss: 0.0839, Generator Loss: 0.0799, Series Loss: 0.0035, Class Loss: 0.2462, Accuracy: 0.1852
# Epoch [341/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0796, Series Loss: 0.0035, Class Loss: 0.2462, Accuracy: 0.1728
# Epoch [342/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0797, Series Loss: 0.0035, Class Loss: 0.2461, Accuracy: 0.2037
# Epoch [343/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0798, Series Loss: 0.0036, Class Loss: 0.2461, Accuracy: 0.1914
# Epoch [344/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0800, Series Loss: 0.0036, Class Loss: 0.2463, Accuracy: 0.1852
# Epoch [345/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0801, Series Loss: 0.0037, Class Loss: 0.2462, Accuracy: 0.1914
# Epoch [346/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0799, Series Loss: 0.0037, Class Loss: 0.2461, Accuracy: 0.1728
# Epoch [347/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0799, Series Loss: 0.0038, Class Loss: 0.2461, Accuracy: 0.1667
# Epoch [348/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0799, Series Loss: 0.0038, Class Loss: 0.2463, Accuracy: 0.1975
# Epoch [349/4000], Discriminator Loss: 0.0847, Generator Loss: 0.0799, Series Loss: 0.0039, Class Loss: 0.2462, Accuracy: 0.1728
# Epoch [350/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0799, Series Loss: 0.0039, Class Loss: 0.2464, Accuracy: 0.1543
# Epoch [351/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0797, Series Loss: 0.0040, Class Loss: 0.2463, Accuracy: 0.1481
# Epoch [352/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0799, Series Loss: 0.0040, Class Loss: 0.2463, Accuracy: 0.1667
# Epoch [353/4000], Discriminator Loss: 0.0844, Generator Loss: 0.0800, Series Loss: 0.0041, Class Loss: 0.2463, Accuracy: 0.1728
# Epoch [354/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0805, Series Loss: 0.0042, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [355/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0804, Series Loss: 0.0042, Class Loss: 0.2464, Accuracy: 0.1667
# Epoch [356/4000], Discriminator Loss: 0.0845, Generator Loss: 0.0801, Series Loss: 0.0042, Class Loss: 0.2463, Accuracy: 0.1728
# Epoch [357/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0799, Series Loss: 0.0043, Class Loss: 0.2464, Accuracy: 0.1667
# Epoch [358/4000], Discriminator Loss: 0.0846, Generator Loss: 0.0801, Series Loss: 0.0044, Class Loss: 0.2463, Accuracy: 0.1790
# Epoch [359/4000], Discriminator Loss: 0.0841, Generator Loss: 0.0799, Series Loss: 0.0044, Class Loss: 0.2465, Accuracy: 0.1420
# Epoch [360/4000], Discriminator Loss: 0.0843, Generator Loss: 0.0802, Series Loss: 0.0045, Class Loss: 0.2467, Accuracy: 0.1481
# Epoch [361/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0799, Series Loss: 0.0045, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [362/4000], Discriminator Loss: 0.0842, Generator Loss: 0.0806, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1481
# Epoch [363/4000], Discriminator Loss: 0.0847, Generator Loss: 0.0801, Series Loss: 0.0048, Class Loss: 0.2467, Accuracy: 0.1543
# Epoch [364/4000], Discriminator Loss: 0.0849, Generator Loss: 0.0802, Series Loss: 0.0048, Class Loss: 0.2468, Accuracy: 0.1543
# Epoch [365/4000], Discriminator Loss: 0.0851, Generator Loss: 0.0797, Series Loss: 0.0048, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [366/4000], Discriminator Loss: 0.0854, Generator Loss: 0.0801, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1605
# Epoch [367/4000], Discriminator Loss: 0.0853, Generator Loss: 0.0798, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1605
# Epoch [368/4000], Discriminator Loss: 0.0847, Generator Loss: 0.0802, Series Loss: 0.0049, Class Loss: 0.2468, Accuracy: 0.1420
# Epoch [369/4000], Discriminator Loss: 0.0848, Generator Loss: 0.0802, Series Loss: 0.0050, Class Loss: 0.2468, Accuracy: 0.1728
# Epoch [370/4000], Discriminator Loss: 0.0854, Generator Loss: 0.0798, Series Loss: 0.0051, Class Loss: 0.2469, Accuracy: 0.1481
# Epoch [371/4000], Discriminator Loss: 0.0848, Generator Loss: 0.0800, Series Loss: 0.0051, Class Loss: 0.2468, Accuracy: 0.1667
# Epoch [372/4000], Discriminator Loss: 0.0851, Generator Loss: 0.0805, Series Loss: 0.0052, Class Loss: 0.2468, Accuracy: 0.1481
# Epoch [373/4000], Discriminator Loss: 0.0857, Generator Loss: 0.0796, Series Loss: 0.0052, Class Loss: 0.2469, Accuracy: 0.1481
# ...
# Epoch [2974/4000], Discriminator Loss: 0.0920, Generator Loss: 0.0792, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [2975/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0788, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [2976/4000], Discriminator Loss: 0.0912, Generator Loss: 0.0786, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1790
# Epoch [2977/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0782, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1605
# Epoch [2978/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0787, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [2979/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0778, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1914
# Epoch [2980/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0782, Series Loss: 0.0046, Class Loss: 0.2467, Accuracy: 0.1914
# Epoch [2981/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0783, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [2982/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0778, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [2983/4000], Discriminator Loss: 0.0907, Generator Loss: 0.0777, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [2984/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0784, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.2037
# Epoch [2985/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0781, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1790
# Epoch [2986/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0786, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [2987/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0781, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1728
# Epoch [2988/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0787, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [2989/4000], Discriminator Loss: 0.0912, Generator Loss: 0.0780, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [2990/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0782, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [2991/4000], Discriminator Loss: 0.0915, Generator Loss: 0.0782, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [2992/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0785, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [2993/4000], Discriminator Loss: 0.0906, Generator Loss: 0.0799, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1914
# Epoch [2994/4000], Discriminator Loss: 0.0902, Generator Loss: 0.0797, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1667
# Epoch [2995/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0796, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [2996/4000], Discriminator Loss: 0.0902, Generator Loss: 0.0794, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1790
# Epoch [2997/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0791, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1914
# Epoch [2998/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0782, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1667
# Epoch [2999/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0782, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3000/4000], Discriminator Loss: 0.0906, Generator Loss: 0.0791, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3001/4000], Discriminator Loss: 0.0907, Generator Loss: 0.0787, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1543
# Epoch [3002/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0790, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [3003/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0793, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [3004/4000], Discriminator Loss: 0.0902, Generator Loss: 0.0800, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3005/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0784, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3006/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0785, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1790
# Epoch [3007/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0793, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1852
# Epoch [3008/4000], Discriminator Loss: 0.0903, Generator Loss: 0.0785, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3009/4000], Discriminator Loss: 0.0908, Generator Loss: 0.0790, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1852
# Epoch [3010/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0788, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1667
# Epoch [3011/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0780, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3012/4000], Discriminator Loss: 0.0906, Generator Loss: 0.0780, Series Loss: 0.0047, Class Loss: 0.2464, Accuracy: 0.1728
# Epoch [3013/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0788, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3014/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0788, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3015/4000], Discriminator Loss: 0.0896, Generator Loss: 0.0786, Series Loss: 0.0046, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3016/4000], Discriminator Loss: 0.0912, Generator Loss: 0.0787, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3017/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0789, Series Loss: 0.0046, Class Loss: 0.2466, Accuracy: 0.1605
# Epoch [3018/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0793, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3019/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0786, Series Loss: 0.0048, Class Loss: 0.2464, Accuracy: 0.1728
# Epoch [3020/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0790, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3021/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0790, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3022/4000], Discriminator Loss: 0.0899, Generator Loss: 0.0784, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3023/4000], Discriminator Loss: 0.0910, Generator Loss: 0.0787, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1852
# Epoch [3024/4000], Discriminator Loss: 0.0900, Generator Loss: 0.0787, Series Loss: 0.0047, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3025/4000], Discriminator Loss: 0.0904, Generator Loss: 0.0785, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1481
# Epoch [3026/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0781, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3027/4000], Discriminator Loss: 0.0911, Generator Loss: 0.0787, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.2037
# Epoch [3028/4000], Discriminator Loss: 0.0905, Generator Loss: 0.0786, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3029/4000], Discriminator Loss: 0.0913, Generator Loss: 0.0780, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3030/4000], Discriminator Loss: 0.0916, Generator Loss: 0.0778, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1975
# Epoch [3031/4000], Discriminator Loss: 0.0918, Generator Loss: 0.0778, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1852
# Epoch [3032/4000], Discriminator Loss: 0.0907, Generator Loss: 0.0784, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1790
# Epoch [3033/4000], Discriminator Loss: 0.0919, Generator Loss: 0.0780, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3034/4000], Discriminator Loss: 0.0909, Generator Loss: 0.0781, Series Loss: 0.0048, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3035/4000], Discriminator Loss: 0.0923, Generator Loss: 0.0770, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1481
# Epoch [3036/4000], Discriminator Loss: 0.0929, Generator Loss: 0.0774, Series Loss: 0.0048, Class Loss: 0.2467, Accuracy: 0.1543
# Epoch [3037/4000], Discriminator Loss: 0.0938, Generator Loss: 0.0762, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3038/4000], Discriminator Loss: 0.0944, Generator Loss: 0.0769, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1852
# Epoch [3039/4000], Discriminator Loss: 0.0954, Generator Loss: 0.0754, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1790
# Epoch [3040/4000], Discriminator Loss: 0.0956, Generator Loss: 0.0757, Series Loss: 0.0048, Class Loss: 0.2465, Accuracy: 0.1358
# Epoch [3041/4000], Discriminator Loss: 0.0966, Generator Loss: 0.0748, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3042/4000], Discriminator Loss: 0.0976, Generator Loss: 0.0753, Series Loss: 0.0047, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3043/4000], Discriminator Loss: 0.0981, Generator Loss: 0.0752, Series Loss: 0.0047, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [3044/4000], Discriminator Loss: 0.0966, Generator Loss: 0.0751, Series Loss: 0.0049, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [3045/4000], Discriminator Loss: 0.0960, Generator Loss: 0.0740, Series Loss: 0.0048, Class Loss: 0.2467, Accuracy: 0.1852
# Epoch [3046/4000], Discriminator Loss: 0.0967, Generator Loss: 0.0748, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3047/4000], Discriminator Loss: 0.0977, Generator Loss: 0.0747, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3048/4000], Discriminator Loss: 0.0974, Generator Loss: 0.0745, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3049/4000], Discriminator Loss: 0.0986, Generator Loss: 0.0742, Series Loss: 0.0049, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3050/4000], Discriminator Loss: 0.0979, Generator Loss: 0.0750, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [3051/4000], Discriminator Loss: 0.0973, Generator Loss: 0.0747, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3052/4000], Discriminator Loss: 0.0992, Generator Loss: 0.0747, Series Loss: 0.0048, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3053/4000], Discriminator Loss: 0.0985, Generator Loss: 0.0750, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3054/4000], Discriminator Loss: 0.0963, Generator Loss: 0.0748, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3055/4000], Discriminator Loss: 0.0988, Generator Loss: 0.0738, Series Loss: 0.0050, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3056/4000], Discriminator Loss: 0.1016, Generator Loss: 0.0741, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1790
# Epoch [3057/4000], Discriminator Loss: 0.0999, Generator Loss: 0.0749, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3058/4000], Discriminator Loss: 0.0993, Generator Loss: 0.0746, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [3059/4000], Discriminator Loss: 0.0999, Generator Loss: 0.0733, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3060/4000], Discriminator Loss: 0.0998, Generator Loss: 0.0750, Series Loss: 0.0050, Class Loss: 0.2465, Accuracy: 0.1852
# Epoch [3061/4000], Discriminator Loss: 0.1026, Generator Loss: 0.0727, Series Loss: 0.0050, Class Loss: 0.2465, Accuracy: 0.1605
# Epoch [3062/4000], Discriminator Loss: 0.1003, Generator Loss: 0.0743, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1605
# Epoch [3063/4000], Discriminator Loss: 0.1009, Generator Loss: 0.0731, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3064/4000], Discriminator Loss: 0.1026, Generator Loss: 0.0740, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1728
# Epoch [3065/4000], Discriminator Loss: 0.1023, Generator Loss: 0.0731, Series Loss: 0.0049, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3066/4000], Discriminator Loss: 0.1034, Generator Loss: 0.0731, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1605
# Epoch [3067/4000], Discriminator Loss: 0.1031, Generator Loss: 0.0736, Series Loss: 0.0049, Class Loss: 0.2467, Accuracy: 0.1420
# Epoch [3068/4000], Discriminator Loss: 0.1014, Generator Loss: 0.0733, Series Loss: 0.0049, Class Loss: 0.2467, Accuracy: 0.1605
# Epoch [3069/4000], Discriminator Loss: 0.1005, Generator Loss: 0.0748, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3070/4000], Discriminator Loss: 0.1008, Generator Loss: 0.0727, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3071/4000], Discriminator Loss: 0.0989, Generator Loss: 0.0748, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3072/4000], Discriminator Loss: 0.1009, Generator Loss: 0.0741, Series Loss: 0.0051, Class Loss: 0.2465, Accuracy: 0.1605
# Epoch [3073/4000], Discriminator Loss: 0.1039, Generator Loss: 0.0740, Series Loss: 0.0051, Class Loss: 0.2468, Accuracy: 0.1543
# Epoch [3074/4000], Discriminator Loss: 0.1010, Generator Loss: 0.0735, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1420
# Epoch [3075/4000], Discriminator Loss: 0.1024, Generator Loss: 0.0738, Series Loss: 0.0051, Class Loss: 0.2466, Accuracy: 0.1914
# Epoch [3076/4000], Discriminator Loss: 0.1001, Generator Loss: 0.0741, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3077/4000], Discriminator Loss: 0.1011, Generator Loss: 0.0733, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3078/4000], Discriminator Loss: 0.1024, Generator Loss: 0.0740, Series Loss: 0.0051, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3079/4000], Discriminator Loss: 0.1035, Generator Loss: 0.0729, Series Loss: 0.0051, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3080/4000], Discriminator Loss: 0.1000, Generator Loss: 0.0740, Series Loss: 0.0049, Class Loss: 0.2465, Accuracy: 0.1667
# Epoch [3081/4000], Discriminator Loss: 0.1013, Generator Loss: 0.0734, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3082/4000], Discriminator Loss: 0.1007, Generator Loss: 0.0731, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3083/4000], Discriminator Loss: 0.0996, Generator Loss: 0.0744, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1420
# Epoch [3084/4000], Discriminator Loss: 0.1000, Generator Loss: 0.0737, Series Loss: 0.0049, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3085/4000], Discriminator Loss: 0.1013, Generator Loss: 0.0746, Series Loss: 0.0050, Class Loss: 0.2468, Accuracy: 0.1543
# Epoch [3086/4000], Discriminator Loss: 0.0991, Generator Loss: 0.0740, Series Loss: 0.0051, Class Loss: 0.2466, Accuracy: 0.1543
# Epoch [3087/4000], Discriminator Loss: 0.1001, Generator Loss: 0.0740, Series Loss: 0.0051, Class Loss: 0.2466, Accuracy: 0.1605
# Epoch [3088/4000], Discriminator Loss: 0.0991, Generator Loss: 0.0748, Series Loss: 0.0050, Class Loss: 0.2468, Accuracy: 0.1481
# Epoch [3089/4000], Discriminator Loss: 0.1009, Generator Loss: 0.0738, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1543
# Epoch [3090/4000], Discriminator Loss: 0.0995, Generator Loss: 0.0749, Series Loss: 0.0050, Class Loss: 0.2467, Accuracy: 0.1543
# Epoch [3091/4000], Discriminator Loss: 0.0998, Generator Loss: 0.0746, Series Loss: 0.0051, Class Loss: 0.2467, Accuracy: 0.1667
# Epoch [3092/4000], Discriminator Loss: 0.1006, Generator Loss: 0.0741, Series Loss: 0.0049, Class Loss: 0.2468, Accuracy: 0.1420
# Epoch [3093/4000], Discriminator Loss: 0.1027, Generator Loss: 0.0732, Series Loss: 0.0051, Class Loss: 0.2466, Accuracy: 0.1728
# Epoch [3094/4000], Discriminator Loss: 0.0988, Generator Loss: 0.0744, Series Loss: 0.0050, Class Loss: 0.2466, Accuracy: 0.1667
# Epoch [3095/4000], Discriminator Loss: 0.0990, Generator Loss: 0.0738, Series Loss: 0.0050, Class Loss: 0.2468, Accuracy: 0.1358
# Epoch [3096/4000], Discriminator Loss: 0.0995, Generator Loss: 0.0738, Series Loss: 0.0051, Class Loss: 0.2467, Accuracy: 0.1728
# Epoch [3097/4000], Discriminator Loss: 0.1010, Generator Loss: 0.0745, Series Loss: 0.0051, Class Loss: 0.2465, Accuracy: 0.1790

# %%
g_curve = [i.cpu() for i in G_loss]
plt.plot(g_curve)

# %%
d_curve = [i.cpu() for i in D_loss]
plt.plot(d_curve)

# %%
s_curve = [i.cpu() for i in S_loss]
plt.plot(s_curve)

# %%
c_curve = [i.cpu() for i in C_loss]
plt.plot(c_curve)

# %%
a_curve = [i for i in accs]
plt.plot(a_curve)

# %%
output = generated_img.cpu().detach()
# output = torch.reshape(output, (output.size(1), output.size(0)))

# %%
plt.plot(output.numpy()[1])

# %%
def transpose_list(my_list):
    transposed_list = list(zip(*my_list))
    for i in range(len(transposed_list)):
        transposed_list[i] = list(transposed_list[i])
    return transposed_list

# %%
transposed_list = transpose_list(series)

# %%
plt.plot(series[0])

# %%
auth = []
for step,(img,label) in enumerate(dataloader):
        img =img.to(device) #把数据放到设备上
        label = label.to(device)
        size = img.shape[0] #img的第一位是size,获取批次的大小
        random_seed = torch.randn(size,100,device=device)
        
        #在生成器上去计算生成器的损失，优化目标是判别器上的参数
        generated_img = gen(random_seed,label) #得到生成的图片
        generated_img = torch.reshape(generated_img, (generated_img.size(0), generated_img.size(2)))
        class_output = cls(torch.reshape(generated_img, (generated_img.size(0), 1, generated_img.size(1))))
        auth.append(class_output)

# %%
auth

# %%
path = 'seed{}'.format(seed) + 'G{}'.format(generator_rate) + 'D{}'.format(discriminator_rate)
isExists=os.path.exists(path)
if not isExists:
    os.mkdir(path)
path = path + '/S{}'.format(continue_loss_weight) + 'C{}'.format(class_loss_weight)
os.mkdir(path)
torch.save(gen, path + '/generator.pt')

# %%
torch.save(dis, path + "/discriminator.pt")

# %%
code = []
for _, (_, _) in enumerate(dataloader):
    random_seed = torch.randn(size,100,device=device)
    code.append(random_seed.cpu().numpy())

# %%
np.array(code)

# %%
np.save(path + '/code.npy', code)

# %%
torch.save(accs, path + '/accs.pt')
